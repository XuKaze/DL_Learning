# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %% [markdown]
# # Data Downloading & Unzid

# %%
 # !gdown --id 1thV_9B1Noyf2Q91FTVJwGrS-Xh0BjqFT
 # !unzip '/content/only2speaker.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: min/tr/mix/01aa010i_4.4784_209c0109_-4.4784.wav
#   inflating: min/tr/mix/01ao0308_0.88225_209o0101_-0.88225.wav
#   inflating: min/tr/mix/01ao0318_4.2526_209c010m_-4.2526.wav
#   inflating: min/tr/mix/01ao030e_2.2716_209o010c_-2.2716.wav
#   inflating: min/tr/mix/01ac0216_3.7128_209o0102_-3.7128.wav
#   inflating: min/tr/mix/01ao030r_4.8083_209a010y_-4.8083.wav
#   inflating: min/tr/mix/01ac020a_3.0031_209a010h_-3.0031.wav
#   inflating: min/tr/mix/01ac0211_3.1823_209a010p_-3.1823.wav
#   inflating: min/tr/mix/01aa0103_4.3498_209o0109_-4.3498.wav
#   inflating: min/tr/mix/01aa010n_4.0892_209o010h_-4.0892.wav
#   inflating: min/tr/mix/01aa010k_1.9741_209a010c_-1.9741.wav
#   inflating: min/tr/mix/01ao030r_0.072955_209a0103_-0.072955.wav
#   inflating: min/tr/mix/01aa010f_3.325_209a010n_-3.325.wav
#   inflating: min/tr/mix/01ac0214_1.633_209a0102_-1.633.wav
#   inflating: min/tr/mix/01ao0309_4.9094_209o0102_-4.9094.wav
#   inflating: min/tr/mix/01ac020k_4.7815_209o0108_-4.7815.wav
#   inflating: min/tr/mix/01ao030w_2.2298_209c010p_-2.2298.wav
#   inflating: min/tr/mix/01ao030j_4.9107_209o010p_-4.9107.wav
#   inflating: min/tr/mix/01aa010n_0.45997_209a0101_-0.45997.wav
#   inflating: min/tr/mix/01aa0114_3.0911_209c010g_-3.0911.wav
#   inflating: min/tr/mix/01aa010y_1.4362_209c0109_-1.4362.wav
#   inflating: min/tr/mix/01ac020v_1.2061_209a0106_-1.2061.wav
#   inflating: min/tr/mix/01ac020z_2.8033_209a010v_-2.8033.wav
#   inflating: min/tr/mix/01ao030l_4.7023_209c010b_-4.7023.wav
#   inflating: min/tr/mix/01ao030v_1.2459_209o010a_-1.2459.wav
#   inflating: min/tr/mix/01ac021g_1.5779_209o010o_-1.5779.wav
#   inflating: min/tr/mix/01ac021c_3.1485_209a010r_-3.1485.wav
#   inflating: min/tr/mix/01ao031b_0.48632_209o010j_-0.48632.wav
#   inflating: min/tr/mix/01ac020x_3.6657_209a010u_-3.6657.wav
#   inflating: min/tr/mix/01aa0112_3.6648_209a0106_-3.6648.wav
#   inflating: min/tr/mix/01aa010i_1.5444_209c0102_-1.5444.wav
#   inflating: min/tr/mix/01aa010v_3.7187_209a010i_-3.7187.wav
#   inflating: min/tr/mix/01ac020r_3.7915_209c010b_-3.7915.wav
#   inflating: min/tr/mix/01ac0219_2.9604_209a010f_-2.9604.wav
#   inflating: min/tr/mix/01ac020q_2.169_209a010n_-2.169.wav
#   inflating: min/tr/mix/01aa010y_2.5537_209c010h_-2.5537.wav
#   inflating: min/tr/mix/01ac0206_2.6901_209a010p_-2.6901.wav
#   inflating: min/tr/mix/01ac020g_0.85349_209a010i_-0.85349.wav
#   inflating: min/tr/mix/01aa010t_4.9641_209c0106_-4.9641.wav
#   inflating: min/tr/mix/01ac020e_4.9481_209o010l_-4.9481.wav
#   inflating: min/tr/mix/01aa010c_3.814_209o010a_-3.814.wav
#   inflating: min/tr/mix/01ao031b_2.4704_209a0112_-2.4704.wav
#   inflating: min/tr/mix/01ac020n_1.7978_209c0103_-1.7978.wav
#   inflating: min/tr/mix/01ac0201_2.7444_209a0101_-2.7444.wav
#   inflating: min/tr/mix/01ao031c_2.5982_209c0101_-2.5982.wav
#   inflating: min/tr/mix/01ac0201_2.1744_209c010b_-2.1744.wav
#   inflating: min/tr/mix/01ao030q_4.6739_209a0105_-4.6739.wav
#   inflating: min/tr/mix/01aa0101_2.4406_209c010i_-2.4406.wav
#   inflating: min/tr/mix/01aa0109_2.7214_209c010p_-2.7214.wav
#   inflating: min/tr/mix/01ao0312_2.1832_209c0103_-2.1832.wav
#   inflating: min/tr/mix/01ao0317_1.0712_209a010w_-1.0712.wav
#   inflating: min/tr/mix/01ac020p_3.2904_209c0101_-3.2904.wav
#   inflating: min/tr/mix/01ao030x_1.6655_209a0112_-1.6655.wav
#   inflating: min/tr/mix/01aa0111_1.2639_209a0110_-1.2639.wav
#   inflating: min/tr/mix/01ao030e_1.9087_209c010f_-1.9087.wav
#   inflating: min/tr/mix/01ac020i_3.9686_209c010q_-3.9686.wav
#   inflating: min/tr/mix/01ac020s_3.6829_209c010m_-3.6829.wav
#   inflating: min/tr/mix/01ao030b_0.81185_209a010o_-0.81185.wav
#   inflating: min/tr/mix/01aa0102_2.9121_209a0101_-2.9121.wav
#   inflating: min/tr/mix/01ao0308_0.45058_209a0110_-0.45058.wav
#   inflating: min/tr/mix/01ac020g_1.7851_209a0110_-1.7851.wav
#   inflating: min/tr/mix/01aa010j_4.7987_209o010p_-4.7987.wav
#   inflating: min/tr/mix/01ac021b_1.0511_209a010x_-1.0511.wav
#   inflating: min/tr/mix/01ao030w_2.4_209c010h_-2.4.wav
#   inflating: min/tr/mix/01ao030d_0.89471_209c0103_-0.89471.wav
#   inflating: min/tr/mix/01ac0218_3.7675_209c0101_-3.7675.wav
#   inflating: min/tr/mix/01ac020i_3.582_209a0109_-3.582.wav
#   inflating: min/tr/mix/01ac0204_4.2138_209a010e_-4.2138.wav
#   inflating: min/tr/mix/01aa0111_0.35184_209c010c_-0.35184.wav
#   inflating: min/tr/mix/01aa010v_3.5112_209o010l_-3.5112.wav
#   inflating: min/tr/mix/01ac0217_2.6048_209c0108_-2.6048.wav
#   inflating: min/tr/mix/01ao031c_2.6243_209o010k_-2.6243.wav
#   inflating: min/tr/mix/01ac0213_1.224_209a010c_-1.224.wav
#   inflating: min/tr/mix/01ao0303_3.2013_209c010o_-3.2013.wav
#   inflating: min/tr/mix/01ao030g_3.0279_209o010f_-3.0279.wav
#   inflating: min/tr/mix/01ac020o_2.1874_209a0107_-2.1874.wav
#   inflating: min/tr/mix/01aa0103_3.19_209c010k_-3.19.wav
#   inflating: min/tr/mix/01ac0207_3.0992_209a010a_-3.0992.wav
#   inflating: min/tr/mix/01aa010w_1.8393_209o0105_-1.8393.wav
#   inflating: min/tr/mix/01ao031e_1.3462_209a010k_-1.3462.wav
#   inflating: min/tr/mix/01aa010n_2.3495_209c010n_-2.3495.wav
#   inflating: min/tr/mix/01ac020a_3.7341_209o0107_-3.7341.wav
#   inflating: min/tr/mix/01ao0311_0.88255_209c010a_-0.88255.wav
#   inflating: min/tr/mix/01aa010h_2.9099_209o0106_-2.9099.wav
#   inflating: min/tr/mix/01ao0309_3.9435_209a010a_-3.9435.wav
#   inflating: min/tr/mix/01ac020k_1.414_209c010i_-1.414.wav
#   inflating: min/tr/mix/01ao030s_0.065365_209o010i_-0.065365.wav
#   inflating: min/tr/mix/01aa010t_0.13677_209a010h_-0.13677.wav
#   inflating: min/tr/mix/01ao030k_2.1563_209c010j_-2.1563.wav
#   inflating: min/tr/mix/01aa0106_2.6354_209o0104_-2.6354.wav
#   inflating: min/tr/mix/01ao030a_3.4356_209c010l_-3.4356.wav
#   inflating: min/tr/mix/01aa010r_1.9628_209a010e_-1.9628.wav
#   inflating: min/tr/mix/01aa010e_2.3174_209o010k_-2.3174.wav
#   inflating: min/tr/mix/01ao031c_3.793_209a010b_-3.793.wav
#   inflating: min/tr/mix/01ao030t_0.78862_209a010c_-0.78862.wav
#   inflating: min/tr/mix/01ao030r_3.9096_209c0105_-3.9096.wav
#   inflating: min/tr/mix/01ao0307_4.7414_209c010h_-4.7414.wav
#   inflating: min/tr/mix/01ao030c_4.5763_209a010u_-4.5763.wav
#   inflating: min/tr/mix/01ac020y_2.407_209a010t_-2.407.wav
#   inflating: min/tr/mix/01ao031a_2.101_209o0103_-2.101.wav
#   inflating: min/tr/mix/01ac021f_2.8885_209a010c_-2.8885.wav
#   inflating: min/tr/mix/01aa010o_4.8321_209c010f_-4.8321.wav
#   inflating: min/tr/mix/01aa0103_3.1181_209c0107_-3.1181.wav
#   inflating: min/tr/mix/01aa010z_2.3825_209o010g_-2.3825.wav
#   inflating: min/tr/mix/01ac021b_1.2781_209a010i_-1.2781.wav
#   inflating: min/tr/mix/01ao0313_2.5497_209c010h_-2.5497.wav
#   inflating: min/tr/mix/01ac020o_4.5066_209a0112_-4.5066.wav
#   inflating: min/tr/mix/01ac020f_3.2245_209a010n_-3.2245.wav
#   inflating: min/tr/mix/01ao030q_3.6751_209c010e_-3.6751.wav
#   inflating: min/tr/mix/01ao030k_1.3467_209o010g_-1.3467.wav
#   inflating: min/tr/mix/01ao030l_3.8223_209o0106_-3.8223.wav
#   inflating: min/tr/mix/01aa010z_1.118_209o0102_-1.118.wav
#   inflating: min/tr/mix/01ao0313_0.76765_209a0114_-0.76765.wav
#   inflating: min/tr/mix/01ao030q_2.214_209a0106_-2.214.wav
#   inflating: min/tr/mix/01ac0214_4.035_209o010i_-4.035.wav
#   inflating: min/tr/mix/01ao0314_0.28841_209o010g_-0.28841.wav
#   inflating: min/tr/mix/01ao0318_2.4879_209o010h_-2.4879.wav
#   inflating: min/tr/mix/01ac0207_3.7371_209a010o_-3.7371.wav
#   inflating: min/tr/mix/01ao030l_1.2649_209a010a_-1.2649.wav
#   inflating: min/tr/mix/01ac020b_2.3771_209c010d_-2.3771.wav
#   inflating: min/tr/mix/01ao030d_4.8402_209c010f_-4.8402.wav
#   inflating: min/tr/mix/01ao030q_2.7547_209a010q_-2.7547.wav
#   inflating: min/tr/mix/01ac021d_0.095123_209c010h_-0.095123.wav
#   inflating: min/tr/mix/01ao031b_4.5027_209o010o_-4.5027.wav
#   inflating: min/tr/mix/01ao0310_1.1155_209a0106_-1.1155.wav
#   inflating: min/tr/mix/01aa0108_2.2657_209a010c_-2.2657.wav
#   inflating: min/tr/mix/01ao030f_1.87_209o0104_-1.87.wav
#   inflating: min/tr/mix/01ac020f_1.7809_209c010c_-1.7809.wav
#   inflating: min/tr/mix/01ac020c_2.5837_209a010y_-2.5837.wav
#   inflating: min/tr/mix/01ac020p_1.0542_209a010p_-1.0542.wav
#   inflating: min/tr/mix/01ac020d_3.2799_209o010c_-3.2799.wav
#   inflating: min/tr/mix/01ao030o_0.23048_209a010x_-0.23048.wav
#   inflating: min/tr/mix/01aa010p_0.30883_209a010p_-0.30883.wav
#   inflating: min/tr/mix/01ao0302_2.1137_209c010f_-2.1137.wav
#   inflating: min/tr/mix/01aa0109_2.2839_209a0105_-2.2839.wav
#   inflating: min/tr/mix/01ac0207_0.77708_209o010e_-0.77708.wav
#   inflating: min/tr/mix/01aa010z_2.1439_209a010w_-2.1439.wav
#   inflating: min/tr/mix/01aa010g_2.5413_209c0103_-2.5413.wav
#   inflating: min/tr/mix/01aa010e_4.2907_209c0106_-4.2907.wav
#   inflating: min/tr/mix/01ao030j_3.1382_209c010f_-3.1382.wav
#   inflating: min/tr/mix/01ac020n_0.19803_209a0103_-0.19803.wav
#   inflating: min/tr/mix/01ac020l_0.2896_209a0110_-0.2896.wav
#   inflating: min/tr/mix/01ac0213_3.087_209c0104_-3.087.wav
#   inflating: min/tr/mix/01ac020m_2.3137_209o0101_-2.3137.wav
#   inflating: min/tr/mix/01ao030u_2.6941_209o0104_-2.6941.wav
#   inflating: min/tr/mix/01ao030x_4.6877_209c010a_-4.6877.wav
#   inflating: min/tr/mix/01aa0112_4.0219_209a010t_-4.0219.wav
#   inflating: min/tr/mix/01ao030e_4.1265_209c0105_-4.1265.wav
#   inflating: min/tr/mix/01ao031c_0.000266_209c0107_-0.000266.wav
#   inflating: min/tr/mix/01ac0208_2.6826_209c010c_-2.6826.wav
#   inflating: min/tr/mix/01aa0113_1.6837_209a010z_-1.6837.wav
#   inflating: min/tr/mix/01ac020i_0.9031_209a010g_-0.9031.wav
#   inflating: min/tr/mix/01ac020w_3.1244_209o010l_-3.1244.wav
#   inflating: min/tr/mix/01aa010l_2.8215_209a010j_-2.8215.wav
#   inflating: min/tr/mix/01ac0205_4.53_209o0109_-4.53.wav
#   inflating: min/tr/mix/01ac0211_4.108_209c0102_-4.108.wav
#   inflating: min/tr/mix/01aa010i_3.1779_209o0109_-3.1779.wav
#   inflating: min/tr/mix/01aa010r_2.5595_209o0102_-2.5595.wav
#   inflating: min/tr/mix/01ac020h_2.6353_209c010l_-2.6353.wav
#   inflating: min/tr/mix/01ao031c_2.9579_209a0114_-2.9579.wav
#   inflating: min/tr/mix/01ac021b_0.9737_209a010d_-0.9737.wav
#   inflating: min/tr/mix/01ao030y_1.0635_209a0109_-1.0635.wav
#   inflating: min/tr/mix/01aa0114_1.2825_209a0101_-1.2825.wav
#   inflating: min/tr/mix/01ao030d_0.67431_209c0106_-0.67431.wav
#   inflating: min/tr/mix/01aa010b_0.22377_209a010f_-0.22377.wav
#   inflating: min/tr/mix/01ac021e_3.3734_209a0105_-3.3734.wav
#   inflating: min/tr/mix/01ao0305_1.9384_209c0103_-1.9384.wav
#   inflating: min/tr/mix/01ao0304_1.8819_209a010r_-1.8819.wav
#   inflating: min/tr/mix/01aa010s_0.24169_209c010o_-0.24169.wav
#   inflating: min/tr/mix/01ac0211_1.7627_209a010j_-1.7627.wav
#   inflating: min/tr/mix/01ao0311_2.9285_209o0109_-2.9285.wav
#   inflating: min/tr/mix/01ac020o_1.0142_209o010c_-1.0142.wav
#   inflating: min/tr/mix/01aa010q_3.8594_209o010b_-3.8594.wav
#   inflating: min/tr/mix/01ao0318_3.4364_209c010q_-3.4364.wav
#   inflating: min/tr/mix/01ac020s_4.0909_209a010r_-4.0909.wav
#   inflating: min/tr/mix/01ac020z_2.1339_209c010l_-2.1339.wav
#   inflating: min/tr/mix/01ac0203_3.0632_209a0101_-3.0632.wav
#   inflating: min/tr/mix/01ao0318_0.21493_209c010l_-0.21493.wav
#   inflating: min/tr/mix/01aa010e_2.4455_209a010a_-2.4455.wav
#   inflating: min/tr/mix/01ac021d_4.4199_209a010w_-4.4199.wav
#   inflating: min/tr/mix/01ac020q_1.682_209o010m_-1.682.wav
#   inflating: min/tr/mix/01aa0107_0.69237_209c010g_-0.69237.wav
#   inflating: min/tr/mix/01ao0305_4.1216_209a0110_-4.1216.wav
#   inflating: min/tr/mix/01ac020l_4.2063_209c010l_-4.2063.wav
#   inflating: min/tr/mix/01ac0212_3.4256_209a010f_-3.4256.wav
#   inflating: min/tr/mix/01ac021d_4.1462_209c010b_-4.1462.wav
#   inflating: min/tr/mix/01aa0107_3.7311_209a010r_-3.7311.wav
#   inflating: min/tr/mix/01ac020c_0.6469_209o0108_-0.6469.wav
#   inflating: min/tr/mix/01aa010e_4.6759_209a0112_-4.6759.wav
#   inflating: min/tr/mix/01ao030v_3.8404_209o010j_-3.8404.wav
#   inflating: min/tr/mix/01ao030x_0.54245_209o010g_-0.54245.wav
#   inflating: min/tr/mix/01aa010g_0.73156_209c010q_-0.73156.wav
#   inflating: min/tr/mix/01ac0213_2.4998_209o010m_-2.4998.wav
#   inflating: min/tr/mix/01ac0202_2.7529_209a010c_-2.7529.wav
#   inflating: min/tr/mix/01ao0307_4.311_209c0107_-4.311.wav
#   inflating: min/tr/mix/01aa010x_4.0129_209a0113_-4.0129.wav
#   inflating: min/tr/mix/01ao0307_1.5361_209a0102_-1.5361.wav
#   inflating: min/tr/mix/01ac020z_1.9435_209a010l_-1.9435.wav
#   inflating: min/tr/mix/01ao0305_4.7239_209a010w_-4.7239.wav
#   inflating: min/tr/mix/01ac020u_4.226_209c0106_-4.226.wav
#   inflating: min/tr/mix/01ac0208_4.8827_209a010g_-4.8827.wav
#   inflating: min/tr/mix/01aa010b_3.4868_209a010e_-3.4868.wav
#   inflating: min/tr/mix/01aa010c_1.794_209c010e_-1.794.wav
#   inflating: min/tr/mix/01ac0211_0.45564_209o0101_-0.45564.wav
#   inflating: min/tr/mix/01ac020l_1.6489_209a010w_-1.6489.wav
#   inflating: min/tr/mix/01ao030v_3.902_209c010l_-3.902.wav
#   inflating: min/tr/mix/01ac020o_1.2146_209c0104_-1.2146.wav
#   inflating: min/tr/mix/01ac020p_0.47733_209a0113_-0.47733.wav
#   inflating: min/tr/mix/01ac0204_0.29313_209c010q_-0.29313.wav
#   inflating: min/tr/mix/01aa0103_0.34105_209a0101_-0.34105.wav
#   inflating: min/tr/mix/01ac020t_3.7767_209a010h_-3.7767.wav
#   inflating: min/tr/mix/01aa010h_4.8163_209c0108_-4.8163.wav
#   inflating: min/tr/mix/01aa010w_4.1145_209o010d_-4.1145.wav
#   inflating: min/tr/mix/01ao0303_2.6776_209a010a_-2.6776.wav
#   inflating: min/tr/mix/01ao0312_2.1544_209c010d_-2.1544.wav
#   inflating: min/tr/mix/01aa0112_3.0985_209o010j_-3.0985.wav
#   inflating: min/tr/mix/01ao0317_2.1655_209a010b_-2.1655.wav
#   inflating: min/tr/mix/01ac020u_0.97319_209o010n_-0.97319.wav
#   inflating: min/tr/mix/01aa010g_3.9837_209c0101_-3.9837.wav
#   inflating: min/tr/mix/01ao031e_0.16371_209a0107_-0.16371.wav
#   inflating: min/tr/mix/01ac0201_0.99481_209a010g_-0.99481.wav
#   inflating: min/tr/mix/01ao0316_4.3076_209c0107_-4.3076.wav
#   inflating: min/tr/mix/01ao030l_3.0275_209a0108_-3.0275.wav
#   inflating: min/tr/mix/01ac020j_0.13758_209c010i_-0.13758.wav
#   inflating: min/tr/mix/01aa010n_4.6281_209a0111_-4.6281.wav
#   inflating: min/tr/mix/01aa010g_1.4945_209o010o_-1.4945.wav
#   inflating: min/tr/mix/01ac0214_0.41466_209a010b_-0.41466.wav
#   inflating: min/tr/mix/01aa010j_3.6518_209o010h_-3.6518.wav
#   inflating: min/tr/mix/01aa0111_3.2268_209o010j_-3.2268.wav
#   inflating: min/tr/mix/01ac020h_2.9343_209a010s_-2.9343.wav
#   inflating: min/tr/mix/01ao0316_0.15992_209a010z_-0.15992.wav
#   inflating: min/tr/mix/01aa010c_0.60154_209o010k_-0.60154.wav
#   inflating: min/tr/mix/01aa0113_3.0937_209o0101_-3.0937.wav
#   inflating: min/tr/mix/01aa0113_1.5372_209o0109_-1.5372.wav
#   inflating: min/tr/mix/01ao0315_3.3505_209a010p_-3.3505.wav
#   inflating: min/tr/mix/01ao0311_1.7635_209c0109_-1.7635.wav
#   inflating: min/tr/mix/01aa010d_3.8748_209a010w_-3.8748.wav
#   inflating: min/tr/mix/01aa0112_0.27372_209o010f_-0.27372.wav
#   inflating: min/tr/mix/01aa010s_4.6751_209a010r_-4.6751.wav
#   inflating: min/tr/mix/01ao031c_4.8326_209a0110_-4.8326.wav
#   inflating: min/tr/mix/01aa0105_1.83_209c010k_-1.83.wav
#   inflating: min/tr/mix/01ac020h_2.0303_209a0101_-2.0303.wav
#   inflating: min/tr/mix/01aa010e_1.3745_209a010p_-1.3745.wav
#   inflating: min/tr/mix/01ao030c_4.438_209o010d_-4.438.wav
#   inflating: min/tr/mix/01ac020s_1.1267_209a010z_-1.1267.wav
#   inflating: min/tr/mix/01ac0215_2.3_209a010c_-2.3.wav
#   inflating: min/tr/mix/01ac020p_1.9172_209o0109_-1.9172.wav
#   inflating: min/tr/mix/01aa010z_4.6733_209a010p_-4.6733.wav
#   inflating: min/tr/mix/01aa0104_0.5112_209a010w_-0.5112.wav
#   inflating: min/tr/mix/01aa010i_4.1399_209c010f_-4.1399.wav
#   inflating: min/tr/mix/01ac0211_3.612_209c010m_-3.612.wav
#   inflating: min/tr/mix/01ao0308_3.833_209a0114_-3.833.wav
#   inflating: min/tr/mix/01aa010k_1.9333_209o010f_-1.9333.wav
#   inflating: min/tr/mix/01aa010q_1.6221_209a010x_-1.6221.wav
#   inflating: min/tr/mix/01ac020f_0.67913_209o010o_-0.67913.wav
#   inflating: min/tr/mix/01ao0317_0.97421_209c010o_-0.97421.wav
#   inflating: min/tr/mix/01aa010c_1.8186_209o010d_-1.8186.wav
#   inflating: min/tr/mix/01ac0201_1.61_209c010o_-1.61.wav
#   inflating: min/tr/mix/01ac0206_4.5891_209o010h_-4.5891.wav
#   inflating: min/tr/mix/01ao0314_0.78446_209a010z_-0.78446.wav
#   inflating: min/tr/mix/01aa010b_1.6469_209c010f_-1.6469.wav
#   inflating: min/tr/mix/01ac020d_2.157_209a0102_-2.157.wav
#   inflating: min/tr/mix/01aa0107_2.6884_209o010c_-2.6884.wav
#   inflating: min/tr/mix/01ac020q_4.2976_209c010c_-4.2976.wav
#   inflating: min/tr/mix/01ao030n_0.75723_209a010u_-0.75723.wav
#   inflating: min/tr/mix/01ao030w_1.7854_209c0102_-1.7854.wav
#   inflating: min/tr/mix/01ac020j_3.8928_209a010q_-3.8928.wav
#   inflating: min/tr/mix/01ao0301_0.31985_209a010z_-0.31985.wav
#   inflating: min/tr/mix/01ac0208_4.9333_209o0108_-4.9333.wav
#   inflating: min/tr/mix/01ao030m_3.665_209o010b_-3.665.wav
#   inflating: min/tr/mix/01aa0102_3.5606_209a010g_-3.5606.wav
#   inflating: min/tr/mix/01aa0106_1.6906_209a010e_-1.6906.wav
#   inflating: min/tr/mix/01ac0211_0.88191_209a010x_-0.88191.wav
#   inflating: min/tr/mix/01ac020v_2.8654_209a0102_-2.8654.wav
#   inflating: min/tr/mix/01ao031c_0.58951_209a010d_-0.58951.wav
#   inflating: min/tr/mix/01aa010b_4.4688_209c010k_-4.4688.wav
#   inflating: min/tr/mix/01ao0311_3.2611_209a0106_-3.2611.wav
#   inflating: min/tr/mix/01ao030x_2.3339_209a010r_-2.3339.wav
#   inflating: min/tr/mix/01ao030b_3.1326_209a010n_-3.1326.wav
#   inflating: min/tr/mix/01ac020f_1.6949_209a010y_-1.6949.wav
#   inflating: min/tr/mix/01ac0214_1.1938_209o010c_-1.1938.wav
#   inflating: min/tr/mix/01ao0305_3.7152_209c010c_-3.7152.wav
#   inflating: min/tr/mix/01ao0308_1.1954_209a010v_-1.1954.wav
#   inflating: min/tr/mix/01aa010a_2.5898_209a010p_-2.5898.wav
#   inflating: min/tr/mix/01ac020h_1.7758_209c0104_-1.7758.wav
#   inflating: min/tr/mix/01aa010d_2.956_209a0105_-2.956.wav
#   inflating: min/tr/mix/01ac020x_1.8847_209a0108_-1.8847.wav
#   inflating: min/tr/mix/01ao031e_1.8767_209a010h_-1.8767.wav
#   inflating: min/tr/mix/01ac0213_4.8115_209a010p_-4.8115.wav
#   inflating: min/tr/mix/01ac0204_0.80033_209c010o_-0.80033.wav
#   inflating: min/tr/mix/01ao030f_3.8603_209o0108_-3.8603.wav
#   inflating: min/tr/mix/01ao0304_1.0206_209o010g_-1.0206.wav
#   inflating: min/tr/mix/01ac020r_3.0746_209c0101_-3.0746.wav
#   inflating: min/tr/mix/01ac0214_3.5505_209a0107_-3.5505.wav
#   inflating: min/tr/mix/01ao030l_2.4195_209o010l_-2.4195.wav
#   inflating: min/tr/mix/01ac0205_1.4177_209o010l_-1.4177.wav
#   inflating: min/tr/mix/01aa010f_1.3656_209a0107_-1.3656.wav
#   inflating: min/tr/mix/01ac0210_1.7271_209c010e_-1.7271.wav
#   inflating: min/tr/mix/01ao0316_3.4627_209a010h_-3.4627.wav
#   inflating: min/tr/mix/01ac020g_0.41713_209a0112_-0.41713.wav
#   inflating: min/tr/mix/01aa010o_2.9489_209c0105_-2.9489.wav
#   inflating: min/tr/mix/01ao0304_0.10512_209c010f_-0.10512.wav
#   inflating: min/tr/mix/01ac020f_3.2188_209a010u_-3.2188.wav
#   inflating: min/tr/mix/01ao0302_4.3629_209c010k_-4.3629.wav
#   inflating: min/tr/mix/01aa010l_3.6667_209o0101_-3.6667.wav
#   inflating: min/tr/mix/01aa0114_3.2083_209c010e_-3.2083.wav
#   inflating: min/tr/mix/01ao0304_3.3963_209a010k_-3.3963.wav
#   inflating: min/tr/mix/01ac021b_1.6351_209c010o_-1.6351.wav
#   inflating: min/tr/mix/01ao030z_3.7691_209a0106_-3.7691.wav
#   inflating: min/tr/mix/01ao0304_2.8354_209a010g_-2.8354.wav
#   inflating: min/tr/mix/01aa010i_4.9623_209o010m_-4.9623.wav
#   inflating: min/tr/mix/01ac0213_0.5968_209c010p_-0.5968.wav
#   inflating: min/tr/mix/01ao030e_1.4165_209o010a_-1.4165.wav
#   inflating: min/tr/mix/01ao030f_1.4908_209a010g_-1.4908.wav
#   inflating: min/tr/mix/01ao030y_0.24726_209a010v_-0.24726.wav
#   inflating: min/tr/mix/01aa010g_1.1259_209a0106_-1.1259.wav
#   inflating: min/tr/mix/01ac020a_4.8161_209o0108_-4.8161.wav
#   inflating: min/tr/mix/01ao031e_3.2026_209a010l_-3.2026.wav
#   inflating: min/tr/mix/01aa010a_3.4398_209o0101_-3.4398.wav
#   inflating: min/tr/mix/01ao030u_4.4339_209a010g_-4.4339.wav
#   inflating: min/tr/mix/01aa010q_1.5363_209a0104_-1.5363.wav
#   inflating: min/tr/mix/01ac020j_0.19051_209a010e_-0.19051.wav
#   inflating: min/tr/mix/01ac020o_1.4511_209o010a_-1.4511.wav
#   inflating: min/tr/mix/01ac020h_3.1956_209a0105_-3.1956.wav
#   inflating: min/tr/mix/01ac0212_3.6209_209c0107_-3.6209.wav
#   inflating: min/tr/mix/01ao030u_3.1633_209a0103_-3.1633.wav
#   inflating: min/tr/mix/01ao0304_3.4389_209a0111_-3.4389.wav
#   inflating: min/tr/mix/01ac020m_0.042379_209a010q_-0.042379.wav
#   inflating: min/tr/mix/01ao031a_3.356_209c0107_-3.356.wav
#   inflating: min/tr/mix/01ao030m_2.6273_209c010q_-2.6273.wav
#   inflating: min/tr/mix/01aa0103_4.3476_209a010l_-4.3476.wav
#   inflating: min/tr/mix/01ao030h_0.64665_209o010a_-0.64665.wav
#   inflating: min/tr/mix/01aa010e_4.8561_209o010g_-4.8561.wav
#   inflating: min/tr/mix/01ao031a_3.4773_209o010i_-3.4773.wav
#   inflating: min/tr/mix/01ao030i_0.69068_209a0114_-0.69068.wav
#   inflating: min/tr/mix/01ao030b_0.075944_209c010l_-0.075944.wav
#   inflating: min/tr/mix/01ao0316_3.0654_209a0113_-3.0654.wav
#   inflating: min/tr/mix/01ac020n_2.3335_209a010i_-2.3335.wav
#   inflating: min/tr/mix/01ao0315_0.33634_209o0109_-0.33634.wav
#   inflating: min/tr/mix/01ao030d_1.8203_209a010b_-1.8203.wav
#   inflating: min/tr/mix/01ac0209_4.6729_209a010i_-4.6729.wav
#   inflating: min/tr/mix/01ac0218_4.0076_209a010u_-4.0076.wav
#   inflating: min/tr/mix/01aa0102_3.6743_209a010h_-3.6743.wav
#   inflating: min/tr/mix/01ac020z_3.9135_209a0112_-3.9135.wav
#   inflating: min/tr/mix/01ac0202_2.8815_209a010h_-2.8815.wav
#   inflating: min/tr/mix/01ao031d_0.040134_209c0104_-0.040134.wav
#   inflating: min/tr/mix/01ac020f_4.894_209o010d_-4.894.wav
#   inflating: min/tr/mix/01ao0308_1.7525_209o010k_-1.7525.wav
#   inflating: min/tr/mix/01ac0217_1.2715_209a0102_-1.2715.wav
#   inflating: min/tr/mix/01aa010v_3.7481_209o0105_-3.7481.wav
#   inflating: min/tr/mix/01ac0205_0.72035_209a010p_-0.72035.wav
#   inflating: min/tr/mix/01ao0313_2.6832_209a0111_-2.6832.wav
#   inflating: min/tr/mix/01aa010u_4.2839_209c0108_-4.2839.wav
#   inflating: min/tr/mix/01aa010d_2.5756_209c0105_-2.5756.wav
#   inflating: min/tr/mix/01ao031c_3.7305_209c010p_-3.7305.wav
#   inflating: min/tr/mix/01ao031a_0.82545_209c010p_-0.82545.wav
#   inflating: min/tr/mix/01ao031b_2.7947_209c010h_-2.7947.wav
#   inflating: min/tr/mix/01aa010h_0.84015_209o010k_-0.84015.wav
#   inflating: min/tr/mix/01aa010x_4.6964_209a010f_-4.6964.wav
#   inflating: min/tr/mix/01aa0105_2.9431_209a010j_-2.9431.wav
#   inflating: min/tr/mix/01ac021c_3.4777_209a010v_-3.4777.wav
#   inflating: min/tr/mix/01aa0104_4.9495_209a010c_-4.9495.wav
#   inflating: min/tr/mix/01aa010w_4.6504_209a010p_-4.6504.wav
#   inflating: min/tr/mix/01ao030i_1.8442_209o0108_-1.8442.wav
#   inflating: min/tr/mix/01ao0314_4.4672_209a0113_-4.4672.wav
#   inflating: min/tr/mix/01ac0215_4.593_209c010e_-4.593.wav
#   inflating: min/tr/mix/01aa010d_3.6233_209c010e_-3.6233.wav
#   inflating: min/tr/mix/01ao030t_4.8277_209c010i_-4.8277.wav
#   inflating: min/tr/mix/01ao030w_3.6495_209a010h_-3.6495.wav
#   inflating: min/tr/mix/01aa010c_3.7827_209a0112_-3.7827.wav
#   inflating: min/tr/mix/01aa010f_2.6742_209c0107_-2.6742.wav
#   inflating: min/tr/mix/01aa010b_0.36943_209a010w_-0.36943.wav
#   inflating: min/tr/mix/01ao0307_2.9424_209a010f_-2.9424.wav
#   inflating: min/tr/mix/01ao0306_2.5363_209o010e_-2.5363.wav
#   inflating: min/tr/mix/01ao031a_3.1696_209c010e_-3.1696.wav
#   inflating: min/tr/mix/01ao030q_3.1461_209a010o_-3.1461.wav
#   inflating: min/tr/mix/01aa010q_3.9896_209o010i_-3.9896.wav
#   inflating: min/tr/mix/01ac020x_2.0578_209a010q_-2.0578.wav
#   inflating: min/tr/mix/01ac0216_3.1242_209o0109_-3.1242.wav
#   inflating: min/tr/mix/01aa010c_3.3794_209c0106_-3.3794.wav
#   inflating: min/tr/mix/01ac020m_3.7784_209a0106_-3.7784.wav
#   inflating: min/tr/mix/01ac0216_1.8067_209o010d_-1.8067.wav
#   inflating: min/tr/mix/01aa010e_1.4826_209c010c_-1.4826.wav
#   inflating: min/tr/mix/01ac020e_1.4381_209a010n_-1.4381.wav
#   inflating: min/tr/mix/01aa010h_0.1591_209a010p_-0.1591.wav
#   inflating: min/tr/mix/01ac020n_0.81081_209a0101_-0.81081.wav
#   inflating: min/tr/mix/01ao0317_2.0675_209c0103_-2.0675.wav
#   inflating: min/tr/mix/01aa010j_3.8729_209a0106_-3.8729.wav
#   inflating: min/tr/mix/01aa010g_1.4023_209c010i_-1.4023.wav
#   inflating: min/tr/mix/01ac0216_1.3076_209a010c_-1.3076.wav
#   inflating: min/tr/mix/01aa010g_0.55842_209c010f_-0.55842.wav
#   inflating: min/tr/mix/01ao030n_2.2156_209c010k_-2.2156.wav
#   inflating: min/tr/mix/01ao030h_3.6121_209a0114_-3.6121.wav
#   inflating: min/tr/mix/01ao0303_0.51329_209o010d_-0.51329.wav
#   inflating: min/tr/mix/01ac0219_0.39586_209c010k_-0.39586.wav
#   inflating: min/tr/mix/01ao030m_1.6249_209c0102_-1.6249.wav
#   inflating: min/tr/mix/01ac0201_1.1959_209o010m_-1.1959.wav
#   inflating: min/tr/mix/01aa010l_4.9174_209a010v_-4.9174.wav
#   inflating: min/tr/mix/01ao0303_1.2758_209o0101_-1.2758.wav
#   inflating: min/tr/mix/01ao030c_1.078_209c0109_-1.078.wav
#   inflating: min/tr/mix/01ac020t_0.60877_209o010m_-0.60877.wav
#   inflating: min/tr/mix/01ac0203_0.50159_209c0103_-0.50159.wav
#   inflating: min/tr/mix/01ao030y_4.7144_209c010i_-4.7144.wav
#   inflating: min/tr/mix/01ac020v_3.8364_209a0103_-3.8364.wav
#   inflating: min/tr/mix/01ac0210_0.17145_209o010l_-0.17145.wav
#   inflating: min/tr/mix/01ao030m_3.266_209c0103_-3.266.wav
#   inflating: min/tr/mix/01aa010o_0.97018_209o0107_-0.97018.wav
#   inflating: min/tr/mix/01ac021g_3.6886_209o010k_-3.6886.wav
#   inflating: min/tr/mix/01aa010e_4.0717_209a010f_-4.0717.wav
#   inflating: min/tr/mix/01aa0102_3.5778_209c010j_-3.5778.wav
#   inflating: min/tr/mix/01ac021b_0.54821_209a010y_-0.54821.wav
#   inflating: min/tr/mix/01ac0205_1.155_209o010h_-1.155.wav
#   inflating: min/tr/mix/01aa010s_3.719_209a010x_-3.719.wav
#   inflating: min/tr/mix/01ac020d_3.6927_209a0105_-3.6927.wav
#   inflating: min/tr/mix/01ac0204_1.2704_209o010e_-1.2704.wav
#   inflating: min/tr/mix/01ao030h_3.5794_209a010l_-3.5794.wav
#   inflating: min/tr/mix/01ac020m_1.525_209o010c_-1.525.wav
#   inflating: min/tr/mix/01aa010t_2.8943_209c010a_-2.8943.wav
#   inflating: min/tr/mix/01ac020y_0.77511_209a0109_-0.77511.wav
#   inflating: min/tr/mix/01ac020w_1.0361_209a0102_-1.0361.wav
#   inflating: min/tr/mix/01ao0319_2.7975_209a0105_-2.7975.wav
#   inflating: min/tr/mix/01aa010c_1.2825_209a010c_-1.2825.wav
#   inflating: min/tr/mix/01aa010r_0.19074_209o010p_-0.19074.wav
#   inflating: min/tr/mix/01ao0311_4.0753_209a010k_-4.0753.wav
#   inflating: min/tr/mix/01ac021d_4.5795_209c0104_-4.5795.wav
#   inflating: min/tr/mix/01aa010o_1.5701_209a0102_-1.5701.wav
#   inflating: min/tr/mix/01ao0319_2.8259_209a0108_-2.8259.wav
#   inflating: min/tr/mix/01ac020n_3.0882_209a010c_-3.0882.wav
#   inflating: min/tr/mix/01ao030t_1.7245_209a010u_-1.7245.wav
#   inflating: min/tr/mix/01ao030w_4.8677_209o0106_-4.8677.wav
#   inflating: min/tr/mix/01ao0314_3.3125_209o010j_-3.3125.wav
#   inflating: min/tr/mix/01ao030f_4.7838_209a010m_-4.7838.wav
#   inflating: min/tr/mix/01ao030s_2.142_209a0113_-2.142.wav
#   inflating: min/tr/mix/01ao030n_2.5805_209c0103_-2.5805.wav
#   inflating: min/tr/mix/01ao0309_2.4463_209a010v_-2.4463.wav
#   inflating: min/tr/mix/01ao030w_0.032505_209o010h_-0.032505.wav
#   inflating: min/tr/mix/01ao030r_0.085512_209a010i_-0.085512.wav
#   inflating: min/tr/mix/01ao0317_4.9998_209a010d_-4.9998.wav
#   inflating: min/tr/mix/01aa010j_0.44598_209o0101_-0.44598.wav
#   inflating: min/tr/mix/01aa010y_0.2499_209c010o_-0.2499.wav
#   inflating: min/tr/mix/01aa010k_3.399_209a0102_-3.399.wav
#   inflating: min/tr/mix/01aa0107_4.787_209a010p_-4.787.wav
#   inflating: min/tr/mix/01aa010a_2.0168_209a010s_-2.0168.wav
#   inflating: min/tr/mix/01ao030x_3.36_209a0104_-3.36.wav
#   inflating: min/tr/mix/01ac020l_1.8594_209a010r_-1.8594.wav
#   inflating: min/tr/mix/01ao030x_1.2189_209o010n_-1.2189.wav
#   inflating: min/tr/mix/01ao030j_4.7116_209a0113_-4.7116.wav
#   inflating: min/tr/mix/01ao0318_3.4084_209a0103_-3.4084.wav
#   inflating: min/tr/mix/01aa0110_4.1164_209a0109_-4.1164.wav
#   inflating: min/tr/mix/01ao030t_3.3931_209a0112_-3.3931.wav
#   inflating: min/tr/mix/01ao0302_3.0198_209c0104_-3.0198.wav
#   inflating: min/tr/mix/01ac0212_2.2462_209a0114_-2.2462.wav
#   inflating: min/tr/mix/01ao0301_1.1777_209a0107_-1.1777.wav
#   inflating: min/tr/mix/01ao030f_1.6893_209c0107_-1.6893.wav
#   inflating: min/tr/mix/01ac020e_2.0235_209a010o_-2.0235.wav
#   inflating: min/tr/mix/01ac020a_3.5318_209a010m_-3.5318.wav
#   inflating: min/tr/mix/01ac020t_2.7643_209c0105_-2.7643.wav
#   inflating: min/tr/mix/01aa0113_4.9127_209a0114_-4.9127.wav
#   inflating: min/tr/mix/01ao0309_1.1059_209o010k_-1.1059.wav
#   inflating: min/tr/mix/01ao030r_1.5866_209o010d_-1.5866.wav
#   inflating: min/tr/mix/01ao030o_1.6435_209o010o_-1.6435.wav
#   inflating: min/tr/mix/01aa0109_4.2912_209a0103_-4.2912.wav
#   inflating: min/tr/mix/01ao030r_2.5362_209a010h_-2.5362.wav
#   inflating: min/tr/mix/01ao030v_3.0463_209a010p_-3.0463.wav
#   inflating: min/tr/mix/01ac0213_3.6285_209c010f_-3.6285.wav
#   inflating: min/tr/mix/01ao031e_0.67081_209c010k_-0.67081.wav
#   inflating: min/tr/mix/01aa0111_3.5684_209a010z_-3.5684.wav
#   inflating: min/tr/mix/01ac0214_0.49254_209a010j_-0.49254.wav
#   inflating: min/tr/mix/01ao0302_3.5496_209o010b_-3.5496.wav
#   inflating: min/tr/mix/01ac020b_0.24501_209c0106_-0.24501.wav
#   inflating: min/tr/mix/01ac020i_0.23987_209a0106_-0.23987.wav
#   inflating: min/tr/mix/01ac0212_0.23432_209o010c_-0.23432.wav
#   inflating: min/tr/mix/01ao031e_3.8382_209a010t_-3.8382.wav
#   inflating: min/tr/mix/01ac021a_0.62925_209a0104_-0.62925.wav
#   inflating: min/tr/mix/01aa010h_2.4668_209a010h_-2.4668.wav
#   inflating: min/tr/mix/01ac020r_2.624_209a0102_-2.624.wav
#   inflating: min/tr/mix/01aa010d_2.5319_209a010y_-2.5319.wav
#   inflating: min/tr/mix/01aa010x_2.3123_209o010n_-2.3123.wav
#   inflating: min/tr/mix/01aa010i_3.504_209c010j_-3.504.wav
#   inflating: min/tr/mix/01aa010k_2.8828_209o0108_-2.8828.wav
#   inflating: min/tr/mix/01aa0110_1.204_209c0105_-1.204.wav
#   inflating: min/tr/mix/01ac020a_2.9353_209a0109_-2.9353.wav
#   inflating: min/tr/mix/01ac0215_3.3838_209o010o_-3.3838.wav
#   inflating: min/tr/mix/01ao030e_1.4202_209o010i_-1.4202.wav
#   inflating: min/tr/mix/01ac020k_4.9144_209c0104_-4.9144.wav
#   inflating: min/tr/mix/01ao030g_2.5162_209c010d_-2.5162.wav
#   inflating: min/tr/mix/01ac0206_1.5493_209o010n_-1.5493.wav
#   inflating: min/tr/mix/01ao030z_2.1355_209a0111_-2.1355.wav
#   inflating: min/tr/mix/01ac0214_1.154_209o0101_-1.154.wav
#   inflating: min/tr/mix/01ac020k_4.535_209o010j_-4.535.wav
#   inflating: min/tr/mix/01ao030c_3.1402_209c0108_-3.1402.wav
#   inflating: min/tr/mix/01ac0205_0.81178_209a0103_-0.81178.wav
#   inflating: min/tr/mix/01ao030f_2.3928_209o010o_-2.3928.wav
#   inflating: min/tr/mix/01aa0112_3.7265_209o010m_-3.7265.wav
#   inflating: min/tr/mix/01ao0315_1.1519_209o0103_-1.1519.wav
#   inflating: min/tr/mix/01ao030z_3.1773_209a010d_-3.1773.wav
#   inflating: min/tr/mix/01ao031c_3.064_209o0101_-3.064.wav
#   inflating: min/tr/mix/01ao030f_0.84169_209c010b_-0.84169.wav
#   inflating: min/tr/mix/01ao0313_3.0833_209c010p_-3.0833.wav
#   inflating: min/tr/mix/01ao0319_0.12875_209c010f_-0.12875.wav
#   inflating: min/tr/mix/01aa010d_4.6369_209c010c_-4.6369.wav
#   inflating: min/tr/mix/01ac020x_4.8882_209o0108_-4.8882.wav
#   inflating: min/tr/mix/01ac021e_2.8699_209o010o_-2.8699.wav
#   inflating: min/tr/mix/01ac021f_0.22184_209a010z_-0.22184.wav
#   inflating: min/tr/mix/01ao030g_1.574_209c010f_-1.574.wav
#   inflating: min/tr/mix/01ac020v_3.9002_209c010n_-3.9002.wav
#   inflating: min/tr/mix/01ao030k_4.6018_209c010l_-4.6018.wav
#   inflating: min/tr/mix/01aa0109_3.5854_209c010q_-3.5854.wav
#   inflating: min/tr/mix/01aa010r_4.4699_209o0103_-4.4699.wav
#   inflating: min/tr/mix/01ac020j_0.57324_209a010h_-0.57324.wav
#   inflating: min/tr/mix/01ac0217_2.6344_209o010j_-2.6344.wav
#   inflating: min/tr/mix/01ac0209_0.57391_209o010p_-0.57391.wav
#   inflating: min/tr/mix/01ao030w_0.27887_209o0104_-0.27887.wav
#   inflating: min/tr/mix/01aa010q_3.5076_209a0109_-3.5076.wav
#   inflating: min/tr/mix/01ao030k_0.35388_209a010e_-0.35388.wav
#   inflating: min/tr/mix/01ao0309_1.4879_209c010c_-1.4879.wav
#   inflating: min/tr/mix/01ac020m_2.2724_209o010i_-2.2724.wav
#   inflating: min/tr/mix/01ao030w_4.5168_209a0112_-4.5168.wav
#   inflating: min/tr/mix/01ac020u_2.2043_209o010c_-2.2043.wav
#   inflating: min/tr/mix/01ac021a_3.9058_209a010w_-3.9058.wav
#   inflating: min/tr/mix/01ac021b_2.8313_209c010f_-2.8313.wav
#   inflating: min/tr/mix/01ac020v_3.9279_209c010o_-3.9279.wav
#   inflating: min/tr/mix/01ao030s_3.3262_209o0109_-3.3262.wav
#   inflating: min/tr/mix/01aa010p_1.5316_209a0112_-1.5316.wav
#   inflating: min/tr/mix/01ao0305_1.4626_209a010z_-1.4626.wav
#   inflating: min/tr/mix/01ac021b_3.2864_209o010k_-3.2864.wav
#   inflating: min/tr/mix/01ac0216_2.4225_209o010c_-2.4225.wav
#   inflating: min/tr/mix/01ao0309_4.7922_209c010p_-4.7922.wav
#   inflating: min/tr/mix/01aa010h_1.6216_209c0105_-1.6216.wav
#   inflating: min/tr/mix/01ac0210_3.2743_209a010p_-3.2743.wav
#   inflating: min/tr/mix/01ao030p_0.071566_209a010w_-0.071566.wav
#   inflating: min/tr/mix/01ao030y_4.8902_209c010e_-4.8902.wav
#   inflating: min/tr/mix/01ao030x_3.1709_209o0106_-3.1709.wav
#   inflating: min/tr/mix/01ao030r_2.2745_209c010d_-2.2745.wav
#   inflating: min/tr/mix/01ac0211_2.5317_209a010f_-2.5317.wav
#   inflating: min/tr/mix/01ac020q_1.1607_209c010o_-1.1607.wav
#   inflating: min/tr/mix/01ac021b_4.5748_209a010u_-4.5748.wav
#   inflating: min/tr/mix/01ac020p_2.2432_209c010j_-2.2432.wav
#   inflating: min/tr/mix/01ao0307_2.7776_209a0110_-2.7776.wav
#   inflating: min/tr/mix/01aa010y_2.8132_209o0105_-2.8132.wav
#   inflating: min/tr/mix/01ao0303_0.037466_209c010a_-0.037466.wav
#   inflating: min/tr/mix/01aa0106_0.40324_209a0101_-0.40324.wav
#   inflating: min/tr/mix/01ao031d_2.4062_209o0102_-2.4062.wav
#   inflating: min/tr/mix/01aa010n_0.45882_209a010k_-0.45882.wav
#   inflating: min/tr/mix/01aa0113_0.13812_209o0106_-0.13812.wav
#   inflating: min/tr/mix/01ao0303_1.9336_209a010b_-1.9336.wav
#   inflating: min/tr/mix/01ao030c_3.2569_209o010g_-3.2569.wav
#   inflating: min/tr/mix/01aa010i_2.6053_209a010k_-2.6053.wav
#   inflating: min/tr/mix/01ac020h_1.8255_209a010x_-1.8255.wav
#   inflating: min/tr/mix/01ao030a_1.9893_209a0104_-1.9893.wav
#   inflating: min/tr/mix/01aa0101_2.4833_209o010c_-2.4833.wav
#   inflating: min/tr/mix/01ac021f_3.2679_209o010g_-3.2679.wav
#   inflating: min/tr/mix/01ac020x_2.6098_209a0105_-2.6098.wav
#   inflating: min/tr/mix/01ao030m_4.1822_209o010k_-4.1822.wav
#   inflating: min/tr/mix/01ac0209_1.4066_209c010b_-1.4066.wav
#   inflating: min/tr/mix/01ac0203_0.12649_209a010k_-0.12649.wav
#   inflating: min/tr/mix/01ao031a_0.91624_209c0105_-0.91624.wav
#   inflating: min/tr/mix/01aa0107_2.508_209c010e_-2.508.wav
#   inflating: min/tr/mix/01ac021f_0.57232_209a0106_-0.57232.wav
#   inflating: min/tr/mix/01ao030v_3.4067_209a010a_-3.4067.wav
#   inflating: min/tr/mix/01ac0212_0.12719_209a010w_-0.12719.wav
#   inflating: min/tr/mix/01ac0204_0.79431_209c0101_-0.79431.wav
#   inflating: min/tr/mix/01aa010m_4.2817_209o0103_-4.2817.wav
#   inflating: min/tr/mix/01ac020x_4.5326_209a0103_-4.5326.wav
#   inflating: min/tr/mix/01aa010a_2.3791_209a010q_-2.3791.wav
#   inflating: min/tr/mix/01aa010n_3.358_209c0106_-3.358.wav
#   inflating: min/tr/mix/01aa010i_1.4738_209a010g_-1.4738.wav
#   inflating: min/tr/mix/01aa0114_3.8792_209a010b_-3.8792.wav
#   inflating: min/tr/mix/01ac020v_3.588_209c010f_-3.588.wav
#   inflating: min/tr/mix/01aa0103_3.6235_209o010d_-3.6235.wav
#   inflating: min/tr/mix/01aa010q_4.9935_209a010r_-4.9935.wav
#   inflating: min/tr/mix/01ac020w_0.24163_209o010f_-0.24163.wav
#   inflating: min/tr/mix/01ac0207_1.8908_209c010i_-1.8908.wav
#   inflating: min/tr/mix/01aa0107_2.2084_209a0102_-2.2084.wav
#   inflating: min/tr/mix/01ac020b_2.3501_209a010s_-2.3501.wav
#   inflating: min/tr/mix/01ao030s_1.8757_209a010d_-1.8757.wav
#   inflating: min/tr/mix/01ac020q_4.0437_209c0104_-4.0437.wav
#   inflating: min/tr/mix/01ao0307_2.0672_209a010x_-2.0672.wav
#   inflating: min/tr/mix/01ao0314_4.7514_209o010p_-4.7514.wav
#   inflating: min/tr/mix/01ao0306_2.1123_209a010i_-2.1123.wav
#   inflating: min/tr/mix/01aa010k_0.39748_209a0109_-0.39748.wav
#   inflating: min/tr/mix/01ao030z_3.957_209o010a_-3.957.wav
#   inflating: min/tr/mix/01ac020x_3.444_209a010f_-3.444.wav
#   inflating: min/tr/mix/01ac0219_3.8576_209a010y_-3.8576.wav
#   inflating: min/tr/mix/01ac020v_3.0253_209o010f_-3.0253.wav
#   inflating: min/tr/mix/01ac0210_3.4391_209o010c_-3.4391.wav
#   inflating: min/tr/mix/01ao030n_0.64942_209a010j_-0.64942.wav
#   inflating: min/tr/mix/01aa010c_3.0366_209a010f_-3.0366.wav
#   inflating: min/tr/mix/01aa0111_2.4566_209a0105_-2.4566.wav
#   inflating: min/tr/mix/01ac0206_1.475_209c0101_-1.475.wav
#   inflating: min/tr/mix/01ac020f_4.7093_209c010e_-4.7093.wav
#   inflating: min/tr/mix/01aa010m_4.3308_209c010g_-4.3308.wav
#   inflating: min/tr/mix/01ac020y_3.7334_209a010f_-3.7334.wav
#   inflating: min/tr/mix/01ao030i_1.578_209c010h_-1.578.wav
#   inflating: min/tr/mix/01aa010i_4.2913_209o0102_-4.2913.wav
#   inflating: min/tr/mix/01aa010c_4.1431_209c010c_-4.1431.wav
#   inflating: min/tr/mix/01ao0302_4.0535_209o010p_-4.0535.wav
#   inflating: min/tr/mix/01ao031c_4.9027_209c0108_-4.9027.wav
#   inflating: min/tr/mix/01ao0305_0.92922_209a010h_-0.92922.wav
#   inflating: min/tr/mix/01ac020f_3.8386_209a010p_-3.8386.wav
#   inflating: min/tr/mix/01aa010n_0.9012_209a010b_-0.9012.wav
#   inflating: min/tr/mix/01aa0113_2.8797_209a0102_-2.8797.wav
#   inflating: min/tr/mix/01ac0211_4.8709_209a010k_-4.8709.wav
#   inflating: min/tr/mix/01aa0111_2.1537_209c010k_-2.1537.wav
#   inflating: min/tr/mix/01aa0108_3.2546_209c0104_-3.2546.wav
#   inflating: min/tr/mix/01ac0215_2.7555_209a010n_-2.7555.wav
#   inflating: min/tr/mix/01ao0319_2.4435_209c010m_-2.4435.wav
#   inflating: min/tr/mix/01ao030a_0.12196_209a0114_-0.12196.wav
#   inflating: min/tr/mix/01ac020k_2.5285_209o010o_-2.5285.wav
#   inflating: min/tr/mix/01aa0113_1.9022_209o010k_-1.9022.wav
#   inflating: min/tr/mix/01ao031d_0.11952_209o010m_-0.11952.wav
#   inflating: min/tr/mix/01ao030q_2.9717_209o0105_-2.9717.wav
#   inflating: min/tr/mix/01aa010q_2.2821_209a010u_-2.2821.wav
#   inflating: min/tr/mix/01aa0102_1.5545_209o010j_-1.5545.wav
#   inflating: min/tr/mix/01ao030a_0.45366_209o010n_-0.45366.wav
#   inflating: min/tr/mix/01ao031d_2.631_209c010e_-2.631.wav
#   inflating: min/tr/mix/01ao030t_1.5742_209a010q_-1.5742.wav
#   inflating: min/tr/mix/01ao030j_0.74509_209a0108_-0.74509.wav
#   inflating: min/tr/mix/01aa010h_1.108_209a0107_-1.108.wav
#   inflating: min/tr/mix/01ac0210_2.7929_209o010d_-2.7929.wav
#   inflating: min/tr/mix/01ac020x_2.8154_209o010h_-2.8154.wav
#   inflating: min/tr/mix/01ao0311_0.36976_209o010e_-0.36976.wav
#   inflating: min/tr/mix/01aa010y_0.10153_209a0103_-0.10153.wav
#   inflating: min/tr/mix/01ac0201_0.70283_209c010n_-0.70283.wav
#   inflating: min/tr/mix/01ao030v_4.7261_209c0101_-4.7261.wav
#   inflating: min/tr/mix/01aa010b_2.2272_209c0103_-2.2272.wav
#   inflating: min/tr/mix/01ac020u_2.4775_209a0105_-2.4775.wav
#   inflating: min/tr/mix/01aa010f_2.881_209o010c_-2.881.wav
#   inflating: min/tr/mix/01ao0304_3.1187_209c010e_-3.1187.wav
#   inflating: min/tr/mix/01aa010h_2.3771_209c010b_-2.3771.wav
#   inflating: min/tr/mix/01aa010a_2.6338_209o010a_-2.6338.wav
#   inflating: min/tr/mix/01aa0102_4.3133_209c010f_-4.3133.wav
#   inflating: min/tr/mix/01ao030z_1.3068_209c0102_-1.3068.wav
#   inflating: min/tr/mix/01ao0312_3.0132_209a010h_-3.0132.wav
#   inflating: min/tr/mix/01aa0112_0.90196_209a0107_-0.90196.wav
#   inflating: min/tr/mix/01aa010p_2.2784_209c010a_-2.2784.wav
#   inflating: min/tr/mix/01ac020t_0.29501_209c010o_-0.29501.wav
#   inflating: min/tr/mix/01ac020s_2.029_209o010f_-2.029.wav
#   inflating: min/tr/mix/01aa010r_2.5188_209c010p_-2.5188.wav
#   inflating: min/tr/mix/01ao0315_3.3212_209a010d_-3.3212.wav
#   inflating: min/tr/mix/01ao030d_2.9054_209c010i_-2.9054.wav
#   inflating: min/tr/mix/01aa010z_3.7959_209o010o_-3.7959.wav
#   inflating: min/tr/mix/01ao0303_1.3902_209o0105_-1.3902.wav
#   inflating: min/tr/mix/01aa010j_2.9512_209o010c_-2.9512.wav
#   inflating: min/tr/mix/01ac0209_2.338_209c0108_-2.338.wav
#   inflating: min/tr/mix/01ac0215_1.3944_209a010g_-1.3944.wav
#   inflating: min/tr/mix/01aa010u_2.2965_209o0101_-2.2965.wav
#   inflating: min/tr/mix/01ao030w_1.3064_209o0105_-1.3064.wav
#   inflating: min/tr/mix/01ac020o_2.9476_209a0114_-2.9476.wav
#   inflating: min/tr/mix/01ao0316_0.45198_209o010f_-0.45198.wav
#   inflating: min/tr/mix/01aa010v_4.2024_209c010b_-4.2024.wav
#   inflating: min/tr/mix/01aa0104_3.8161_209o0107_-3.8161.wav
#   inflating: min/tr/mix/01aa010m_2.2854_209a010r_-2.2854.wav
#   inflating: min/tr/mix/01ac020m_2.3976_209c010l_-2.3976.wav
#   inflating: min/tr/mix/01ao031b_0.072976_209c010b_-0.072976.wav
#   inflating: min/tr/mix/01aa010c_4.0836_209c010f_-4.0836.wav
#   inflating: min/tr/mix/01ac0205_3.4046_209o0106_-3.4046.wav
#   inflating: min/tr/mix/01ac020m_0.58732_209o0102_-0.58732.wav
#   inflating: min/tr/mix/01ac020h_1.4821_209a010f_-1.4821.wav
#   inflating: min/tr/mix/01ac021b_3.7744_209c010h_-3.7744.wav
#   inflating: min/tr/mix/01ac021g_3.6549_209o010p_-3.6549.wav
#   inflating: min/tr/mix/01ao0318_1.3735_209a0109_-1.3735.wav
#   inflating: min/tr/mix/01ao030y_2.266_209o010c_-2.266.wav
#   inflating: min/tr/mix/01ao030w_4.7274_209a0104_-4.7274.wav
#   inflating: min/tr/mix/01aa0101_0.62271_209o010i_-0.62271.wav
#   inflating: min/tr/mix/01ac020k_4.7111_209c010q_-4.7111.wav
#   inflating: min/tr/mix/01ao0316_1.5629_209o0104_-1.5629.wav
#   inflating: min/tr/mix/01ac021c_4.0205_209o010n_-4.0205.wav
#   inflating: min/tr/mix/01ao0312_2.9678_209a010m_-2.9678.wav
#   inflating: min/tr/mix/01ac020n_4.7828_209c0106_-4.7828.wav
#   inflating: min/tr/mix/01ao030l_3.0376_209a010u_-3.0376.wav
#   inflating: min/tr/mix/01ao030i_0.59847_209c010i_-0.59847.wav
#   inflating: min/tr/mix/01aa010j_0.20338_209c0107_-0.20338.wav
#   inflating: min/tr/mix/01aa010a_2.8306_209a0109_-2.8306.wav
#   inflating: min/tr/mix/01ac020a_2.3806_209o010j_-2.3806.wav
#   inflating: min/tr/mix/01aa0103_1.3535_209c010d_-1.3535.wav
#   inflating: min/tr/mix/01ao031a_2.5098_209c0103_-2.5098.wav
#   inflating: min/tr/mix/01ao030e_1.7953_209c010j_-1.7953.wav
#   inflating: min/tr/mix/01ac0219_4.0257_209c0103_-4.0257.wav
#   inflating: min/tr/mix/01aa0107_3.2311_209o010f_-3.2311.wav
#   inflating: min/tr/mix/01ac0205_1.1739_209a010n_-1.1739.wav
#   inflating: min/tr/mix/01ao0317_3.2118_209a010i_-3.2118.wav
#   inflating: min/tr/mix/01aa010i_2.1919_209o0101_-2.1919.wav
#   inflating: min/tr/mix/01aa0107_0.094095_209c0103_-0.094095.wav
#   inflating: min/tr/mix/01ac020m_4.4695_209a0111_-4.4695.wav
#   inflating: min/tr/mix/01aa010j_2.7074_209a010a_-2.7074.wav
#   inflating: min/tr/mix/01ac0219_1.0251_209a0104_-1.0251.wav
#   inflating: min/tr/mix/01aa0113_2.3121_209o010p_-2.3121.wav
#   inflating: min/tr/mix/01aa010r_1.6967_209c010k_-1.6967.wav
#   inflating: min/tr/mix/01ao0306_2.0479_209c010b_-2.0479.wav
#   inflating: min/tr/mix/01ao030e_3.9181_209c010k_-3.9181.wav
#   inflating: min/tr/mix/01ac021c_1.5328_209a010d_-1.5328.wav
#   inflating: min/tr/mix/01ac020n_3.6743_209a0113_-3.6743.wav
#   inflating: min/tr/mix/01aa010w_1.5646_209c010d_-1.5646.wav
#   inflating: min/tr/mix/01aa010r_3.82_209o0108_-3.82.wav
#   inflating: min/tr/mix/01ac021d_2.8836_209c0108_-2.8836.wav
#   inflating: min/tr/mix/01ac020i_2.2466_209c0104_-2.2466.wav
#   inflating: min/tr/mix/01ao0310_3.3434_209o010e_-3.3434.wav
#   inflating: min/tr/mix/01ao0314_3.0524_209a010s_-3.0524.wav
#   inflating: min/tr/mix/01ao0311_1.1342_209a0109_-1.1342.wav
#   inflating: min/tr/mix/01ac020h_0.2943_209a0112_-0.2943.wav
#   inflating: min/tr/mix/01ao0310_3.1131_209c010j_-3.1131.wav
#   inflating: min/tr/mix/01ac0219_2.4621_209c0105_-2.4621.wav
#   inflating: min/tr/mix/01ac020c_0.40533_209o0109_-0.40533.wav
#   inflating: min/tr/mix/01ao030y_0.030498_209o010b_-0.030498.wav
#   inflating: min/tr/mix/01aa0102_4.3737_209a0113_-4.3737.wav
#   inflating: min/tr/mix/01ao0302_0.94723_209o0108_-0.94723.wav
#   inflating: min/tr/mix/01ac0214_2.0247_209o0104_-2.0247.wav
#   inflating: min/tr/mix/01ac020c_2.9995_209a010l_-2.9995.wav
#   inflating: min/tr/mix/01ao0308_2.3722_209c0109_-2.3722.wav
#   inflating: min/tr/mix/01aa010f_2.7966_209c010b_-2.7966.wav
#   inflating: min/tr/mix/01ac0205_3.8767_209c010m_-3.8767.wav
#   inflating: min/tr/mix/01ac020s_3.4812_209a010u_-3.4812.wav
#   inflating: min/tr/mix/01ao030f_1.5854_209c010q_-1.5854.wav
#   inflating: min/tr/mix/01ac020x_4.254_209o010k_-4.254.wav
#   inflating: min/tr/mix/01aa010t_1.6858_209o010n_-1.6858.wav
#   inflating: min/tr/mix/01aa0113_0.81105_209c0106_-0.81105.wav
#   inflating: min/tr/mix/01ao0305_3.6569_209o0107_-3.6569.wav
#   inflating: min/tr/mix/01ao030s_4.5674_209a010g_-4.5674.wav
#   inflating: min/tr/mix/01aa0114_2.674_209a010q_-2.674.wav
#   inflating: min/tr/mix/01aa010t_4.3855_209o010l_-4.3855.wav
#   inflating: min/tr/mix/01ac020i_0.39468_209a010c_-0.39468.wav
#   inflating: min/tr/mix/01ao0319_3.356_209a0102_-3.356.wav
#   inflating: min/tr/mix/01aa010a_1.2452_209a010m_-1.2452.wav
#   inflating: min/tr/mix/01aa0105_4.2839_209c0102_-4.2839.wav
#   inflating: min/tr/mix/01aa0113_0.17274_209c0107_-0.17274.wav
#   inflating: min/tr/mix/01aa010o_0.43678_209a010l_-0.43678.wav
#   inflating: min/tr/mix/01aa0112_1.3066_209a010h_-1.3066.wav
#   inflating: min/tr/mix/01ao0316_4.2394_209c010i_-4.2394.wav
#   inflating: min/tr/mix/01ao030l_1.4127_209c010g_-1.4127.wav
#   inflating: min/tr/mix/01ao030m_2.8459_209a010y_-2.8459.wav
#   inflating: min/tr/mix/01ac020f_1.7236_209c010a_-1.7236.wav
#   inflating: min/tr/mix/01aa0111_2.1576_209o010f_-2.1576.wav
#   inflating: min/tr/mix/01aa0109_4.7316_209a010j_-4.7316.wav
#   inflating: min/tr/mix/01ac020c_4.8495_209c010b_-4.8495.wav
#   inflating: min/tr/mix/01aa010l_4.8467_209o010b_-4.8467.wav
#   inflating: min/tr/mix/01ao031b_3.3665_209o010a_-3.3665.wav
#   inflating: min/tr/mix/01aa010b_1.6287_209a0103_-1.6287.wav
#   inflating: min/tr/mix/01ac0204_0.1293_209a0106_-0.1293.wav
#   inflating: min/tr/mix/01ao0312_0.1308_209c010c_-0.1308.wav
#   inflating: min/tr/mix/01ac021e_1.4374_209c010p_-1.4374.wav
#   inflating: min/tr/mix/01ao031a_2.3651_209o0108_-2.3651.wav
#   inflating: min/tr/mix/01aa010r_0.064566_209a0109_-0.064566.wav
#   inflating: min/tr/mix/01ac0214_2.5959_209c0109_-2.5959.wav
#   inflating: min/tr/mix/01ac021f_2.8906_209o010p_-2.8906.wav
#   inflating: min/tr/mix/01aa010s_0.72431_209o0108_-0.72431.wav
#   inflating: min/tr/mix/01ac020t_1.2502_209c0102_-1.2502.wav
#   inflating: min/tr/mix/01ac020s_1.9676_209a010a_-1.9676.wav
#   inflating: min/tr/mix/01aa010w_2.7767_209a010q_-2.7767.wav
#   inflating: min/tr/mix/01aa0103_0.98391_209c010h_-0.98391.wav
#   inflating: min/tr/mix/01aa010e_3.7011_209a010l_-3.7011.wav
#   inflating: min/tr/mix/01ac0205_4.1406_209a010w_-4.1406.wav
#   inflating: min/tr/mix/01ac020y_1.0406_209a0104_-1.0406.wav
#   inflating: min/tr/mix/01ao0309_1.3867_209a010y_-1.3867.wav
#   inflating: min/tr/mix/01ac0203_3.5298_209o010h_-3.5298.wav
#   inflating: min/tr/mix/01ao0315_3.7681_209o010f_-3.7681.wav
#   inflating: min/tr/mix/01ac0213_1.6593_209o010b_-1.6593.wav
#   inflating: min/tr/mix/01ao030r_3.3501_209a010u_-3.3501.wav
# ...
#   inflating: min/tt/s2/01aa0103_4.5597_209a010d_-4.5597.wav
#   inflating: min/tt/s2/01ao0302_0.11245_209o0109_-0.11245.wav
#   inflating: min/tt/s2/01ac020b_3.3672_209a010o_-3.3672.wav
#   inflating: min/tt/s2/01aa0106_3.4279_209o0109_-3.4279.wav
#   inflating: min/tt/s2/01ao030o_2.6988_209a010a_-2.6988.wav
#   inflating: min/tt/s2/01aa010l_1.6714_209a010a_-1.6714.wav
#   inflating: min/tt/s2/01ac021e_0.24176_209a010a_-0.24176.wav
#   inflating: min/tt/s2/01aa010p_2.8004_209o010c_-2.8004.wav
#   inflating: min/tt/s2/01ac0209_4.1548_209a010p_-4.1548.wav
#   inflating: min/tt/s2/01ac020w_2.1041_209c010m_-2.1041.wav
#   inflating: min/tt/s2/01ac020x_2.227_209a010k_-2.227.wav
#   inflating: min/tt/s2/01aa0107_1.1422_209c010b_-1.1422.wav
#   inflating: min/tt/s2/01ao0311_3.387_209a010q_-3.387.wav
#   inflating: min/tt/s2/01ao031e_1.1531_209o010b_-1.1531.wav
#   inflating: min/tt/s2/01ac0207_4.3784_209o0103_-4.3784.wav
#   inflating: min/tt/s2/01ao0317_2.9052_209a0112_-2.9052.wav
#   inflating: min/tt/s2/01ac0202_2.6625_209c010a_-2.6625.wav
#   inflating: min/tt/s2/01ao030d_3.0296_209o010b_-3.0296.wav
#   inflating: min/tt/s2/01ao0304_3.481_209o0108_-3.481.wav
#   inflating: min/tt/s2/01ao030k_2.255_209c0105_-2.255.wav
#   inflating: min/tt/s2/01ao0301_3.1217_209c010g_-3.1217.wav
#   inflating: min/tt/s2/01ac020a_3.7921_209a0101_-3.7921.wav
#   inflating: min/tt/s2/01ao0311_2.1927_209c010d_-2.1927.wav
#   inflating: min/tt/s2/01aa010f_4.9297_209a010g_-4.9297.wav
#   inflating: min/tt/s2/01ac020d_4.2649_209a010r_-4.2649.wav
#   inflating: min/tt/s2/01ao030d_3.3796_209a010e_-3.3796.wav
#   inflating: min/tt/s2/01aa010t_1.2708_209a010j_-1.2708.wav
#   inflating: min/tt/s2/01ao030r_4.7313_209o010i_-4.7313.wav
#   inflating: min/tt/s2/01aa010j_3.919_209c010j_-3.919.wav
#   inflating: min/tt/s2/01ao030y_0.78315_209o010b_-0.78315.wav
#   inflating: min/tt/s2/01ao030j_2.1774_209c0108_-2.1774.wav
#   inflating: min/tt/s2/01ao031e_2.5119_209a0106_-2.5119.wav
#   inflating: min/tt/s2/01aa010d_1.314_209a010g_-1.314.wav
#   inflating: min/tt/s2/01ac020c_1.7021_209c010h_-1.7021.wav
#   inflating: min/tt/s2/01ao0305_1.6166_209c0103_-1.6166.wav
#   inflating: min/tt/s2/01aa0106_1.3352_209c0107_-1.3352.wav
#   inflating: min/tt/s2/01aa010y_4.3665_209a010o_-4.3665.wav
#   inflating: min/tt/s2/01ac020p_4.4811_209a0109_-4.4811.wav
#   inflating: min/tt/s2/01aa010g_3.6773_209a010l_-3.6773.wav
#   inflating: min/tt/s2/01ao030t_2.4237_209a010v_-2.4237.wav
#   inflating: min/tt/s2/01ac020a_4.0848_209a010s_-4.0848.wav
#   inflating: min/tt/s2/01ao0310_3.2648_209a010w_-3.2648.wav
#   inflating: min/tt/s2/01ac020v_2.4171_209o0107_-2.4171.wav
#   inflating: min/tt/s2/01ac021b_3.1975_209o0105_-3.1975.wav
#   inflating: min/tt/s2/01aa0113_2.8184_209a010x_-2.8184.wav
#   inflating: min/tt/s2/01ao030u_2.0726_209o010l_-2.0726.wav
#   inflating: min/tt/s2/01ac020q_0.55115_209a010d_-0.55115.wav
#   inflating: min/tt/s2/01ac020d_3.2831_209a0108_-3.2831.wav
#   inflating: min/tt/s2/01ac020k_3.9671_209o010o_-3.9671.wav
#   inflating: min/tt/s2/01aa010k_2.1247_209a010a_-2.1247.wav
#   inflating: min/tt/s2/01ac020k_0.99002_209o010h_-0.99002.wav
#   inflating: min/tt/s2/01ao030u_1.7102_209a010q_-1.7102.wav
#   inflating: min/tt/s2/01ac020f_4.1179_209c0101_-4.1179.wav
#   inflating: min/tt/s2/01ao030v_0.19159_209a010k_-0.19159.wav
#   inflating: min/tt/s2/01ac0204_4.7097_209o0102_-4.7097.wav
#   inflating: min/tt/s2/01ao0305_0.10154_209c010i_-0.10154.wav
#   inflating: min/tt/s2/01aa010b_0.12432_209o010e_-0.12432.wav
#   inflating: min/tt/s2/01ao0316_1.6981_209a010n_-1.6981.wav
#   inflating: min/tt/s2/01ac020b_3.1468_209c010g_-3.1468.wav
#   inflating: min/tt/s2/01ao031b_2.1841_209a0107_-2.1841.wav
#   inflating: min/tt/s2/01aa010j_0.81737_209o010a_-0.81737.wav
#   inflating: min/tt/s2/01aa010s_4.6717_209o010n_-4.6717.wav
#   inflating: min/tt/s2/01ao030m_0.70183_209a0104_-0.70183.wav
#   inflating: min/tt/s2/01ao030c_2.3661_209a010l_-2.3661.wav
#   inflating: min/tt/s2/01ac020t_2.0334_209c010a_-2.0334.wav
#   inflating: min/tt/s2/01ac020x_3.472_209c0101_-3.472.wav
#   inflating: min/tt/s2/01ao030g_0.80276_209c0107_-0.80276.wav
#   inflating: min/tt/s2/01ac0201_4.8119_209o0103_-4.8119.wav
#   inflating: min/tt/s2/01aa0112_3.8726_209a010y_-3.8726.wav
#   inflating: min/tt/s2/01ac021b_3.3224_209o010j_-3.3224.wav
#   inflating: min/tt/s2/01ac020d_4.3932_209a010i_-4.3932.wav
#   inflating: min/tt/s2/01ac020m_2.0064_209c010p_-2.0064.wav
#   inflating: min/tt/s2/01ao031a_0.88148_209c010c_-0.88148.wav
#   inflating: min/tt/s2/01ac0213_3.3792_209o010b_-3.3792.wav
#   inflating: min/tt/s2/01aa0102_4.0757_209o0108_-4.0757.wav
#   inflating: min/tt/s2/01ac021e_1.9127_209o010p_-1.9127.wav
#   inflating: min/tt/s2/01ao030w_4.9629_209o010d_-4.9629.wav
#   inflating: min/tt/s2/01ao030a_0.51442_209o0106_-0.51442.wav
#   inflating: min/tt/s2/01ao030n_4.3726_209c0104_-4.3726.wav
#   inflating: min/tt/s2/01ao030i_3.6273_209a010g_-3.6273.wav
#   inflating: min/tt/s2/01ac0210_0.7969_209o010h_-0.7969.wav
#   inflating: min/tt/s2/01ac0217_2.6483_209o010a_-2.6483.wav
#   inflating: min/tt/s2/01aa0108_3.4995_209a010n_-3.4995.wav
#   inflating: min/tt/s2/01ac020s_1.3241_209a010o_-1.3241.wav
#   inflating: min/tt/s2/01ac020f_4.4789_209c0102_-4.4789.wav
#   inflating: min/tt/s2/01ao030e_4.5119_209a010w_-4.5119.wav
#   inflating: min/tt/s2/01ao030q_3.327_209c010g_-3.327.wav
#   inflating: min/tt/s2/01ao031d_0.32387_209c010a_-0.32387.wav
#   inflating: min/tt/s2/01aa0108_3.0868_209a0114_-3.0868.wav
#   inflating: min/tt/s2/01ao030q_2.6388_209o010n_-2.6388.wav
#   inflating: min/tt/s2/01aa0114_3.0485_209a0102_-3.0485.wav
#   inflating: min/tt/s2/01ac0215_2.4269_209o010m_-2.4269.wav
#   inflating: min/tt/s2/01ac020e_2.8781_209a010h_-2.8781.wav
#   inflating: min/tt/s2/01ac0217_0.89304_209a010y_-0.89304.wav
#   inflating: min/tt/s2/01ac0210_0.052248_209c0108_-0.052248.wav
#   inflating: min/tt/s2/01ac020r_3.2359_209c0102_-3.2359.wav
#   inflating: min/tt/s2/01aa010m_0.55609_209o010n_-0.55609.wav
#   inflating: min/tt/s2/01ao031a_2.6743_209c010q_-2.6743.wav
#   inflating: min/tt/s2/01ac021g_0.11994_209o0104_-0.11994.wav
#   inflating: min/tt/s2/01ao0315_3.8886_209o010l_-3.8886.wav
#   inflating: min/tt/s2/01ac020i_1.3021_209c010j_-1.3021.wav
#   inflating: min/tt/s2/01ao0310_2.8044_209a010q_-2.8044.wav
#   inflating: min/tt/s2/01ao030c_4.2717_209a010o_-4.2717.wav
#   inflating: min/tt/s2/01ac021b_1.1891_209c010c_-1.1891.wav
#   inflating: min/tt/s2/01aa0113_2.077_209a010h_-2.077.wav
#   inflating: min/tt/s2/01ac0207_2.8373_209o0108_-2.8373.wav
#   inflating: min/tt/s2/01ao0319_1.5938_209a010t_-1.5938.wav
#   inflating: min/tt/s2/01aa010w_2.9732_209o0105_-2.9732.wav
#   inflating: min/tt/s2/01ac0206_3.3107_209o0108_-3.3107.wav
#   inflating: min/tt/s2/01aa010a_4.6492_209c010j_-4.6492.wav
#   inflating: min/tt/s2/01ao031e_1.1699_209c010e_-1.1699.wav
#   inflating: min/tt/s2/01aa010o_3.6821_209c0108_-3.6821.wav
#   inflating: min/tt/s2/01ao030p_4.7378_209o010d_-4.7378.wav
#   inflating: min/tt/s2/01ao030t_1.3371_209a010a_-1.3371.wav
#   inflating: min/tt/s2/01aa010k_3.8019_209a010j_-3.8019.wav
#   inflating: min/tt/s2/01ac0211_1.9537_209a0104_-1.9537.wav
#   inflating: min/tt/s2/01ao030v_2.2043_209c010l_-2.2043.wav
#   inflating: min/tt/s2/01aa010c_2.1421_209a010n_-2.1421.wav
#   inflating: min/tt/s2/01ao0315_4.4713_209c010j_-4.4713.wav
#   inflating: min/tt/s2/01ao030m_0.55878_209o010o_-0.55878.wav
#   inflating: min/tt/s2/01aa010u_1.8095_209c010l_-1.8095.wav
#   inflating: min/tt/s2/01ac020s_1.1303_209a010d_-1.1303.wav
#   inflating: min/tt/s2/01ac020r_4.789_209o010b_-4.789.wav
#   inflating: min/tt/s2/01aa010t_4.862_209a010a_-4.862.wav
#   inflating: min/tt/s2/01aa010t_3.2298_209a010v_-3.2298.wav
#   inflating: min/tt/s2/01ao0308_1.9995_209o010m_-1.9995.wav
#    creating: min/tt/mix/
#   inflating: min/tt/mix/01ao0306_0.84674_209o010m_-0.84674.wav
#   inflating: min/tt/mix/01ao030r_4.025_209c0107_-4.025.wav
#   inflating: min/tt/mix/01aa0106_3.329_209c0103_-3.329.wav
#   inflating: min/tt/mix/01aa0103_4.5597_209a010d_-4.5597.wav
#   inflating: min/tt/mix/01ao0302_0.11245_209o0109_-0.11245.wav
#   inflating: min/tt/mix/01ac020b_3.3672_209a010o_-3.3672.wav
#   inflating: min/tt/mix/01aa0106_3.4279_209o0109_-3.4279.wav
#   inflating: min/tt/mix/01ao030o_2.6988_209a010a_-2.6988.wav
#   inflating: min/tt/mix/01aa010l_1.6714_209a010a_-1.6714.wav
#   inflating: min/tt/mix/01ac021e_0.24176_209a010a_-0.24176.wav
#   inflating: min/tt/mix/01aa010p_2.8004_209o010c_-2.8004.wav
#   inflating: min/tt/mix/01ac0209_4.1548_209a010p_-4.1548.wav
#   inflating: min/tt/mix/01ac020w_2.1041_209c010m_-2.1041.wav
#   inflating: min/tt/mix/01ac020x_2.227_209a010k_-2.227.wav
#   inflating: min/tt/mix/01aa0107_1.1422_209c010b_-1.1422.wav
#   inflating: min/tt/mix/01ao0311_3.387_209a010q_-3.387.wav
#   inflating: min/tt/mix/01ao031e_1.1531_209o010b_-1.1531.wav
#   inflating: min/tt/mix/01ac0207_4.3784_209o0103_-4.3784.wav
#   inflating: min/tt/mix/01ao0317_2.9052_209a0112_-2.9052.wav
#   inflating: min/tt/mix/01ac0202_2.6625_209c010a_-2.6625.wav
#   inflating: min/tt/mix/01ao030d_3.0296_209o010b_-3.0296.wav
#   inflating: min/tt/mix/01ao0304_3.481_209o0108_-3.481.wav
#   inflating: min/tt/mix/01ao030k_2.255_209c0105_-2.255.wav
#   inflating: min/tt/mix/01ao0301_3.1217_209c010g_-3.1217.wav
#   inflating: min/tt/mix/01ac020a_3.7921_209a0101_-3.7921.wav
#   inflating: min/tt/mix/01ao0311_2.1927_209c010d_-2.1927.wav
#   inflating: min/tt/mix/01aa010f_4.9297_209a010g_-4.9297.wav
#   inflating: min/tt/mix/01ac020d_4.2649_209a010r_-4.2649.wav
#   inflating: min/tt/mix/01ao030d_3.3796_209a010e_-3.3796.wav
#   inflating: min/tt/mix/01aa010t_1.2708_209a010j_-1.2708.wav
#   inflating: min/tt/mix/01ao030r_4.7313_209o010i_-4.7313.wav
#   inflating: min/tt/mix/01aa010j_3.919_209c010j_-3.919.wav
#   inflating: min/tt/mix/01ao030y_0.78315_209o010b_-0.78315.wav
#   inflating: min/tt/mix/01ao030j_2.1774_209c0108_-2.1774.wav
#   inflating: min/tt/mix/01ao031e_2.5119_209a0106_-2.5119.wav
#   inflating: min/tt/mix/01aa010d_1.314_209a010g_-1.314.wav
#   inflating: min/tt/mix/01ac020c_1.7021_209c010h_-1.7021.wav
#   inflating: min/tt/mix/01ao0305_1.6166_209c0103_-1.6166.wav
#   inflating: min/tt/mix/01aa0106_1.3352_209c0107_-1.3352.wav
#   inflating: min/tt/mix/01aa010y_4.3665_209a010o_-4.3665.wav
#   inflating: min/tt/mix/01ac020p_4.4811_209a0109_-4.4811.wav
#   inflating: min/tt/mix/01aa010g_3.6773_209a010l_-3.6773.wav
#   inflating: min/tt/mix/01ao030t_2.4237_209a010v_-2.4237.wav
#   inflating: min/tt/mix/01ac020a_4.0848_209a010s_-4.0848.wav
#   inflating: min/tt/mix/01ao0310_3.2648_209a010w_-3.2648.wav
#   inflating: min/tt/mix/01ac020v_2.4171_209o0107_-2.4171.wav
#   inflating: min/tt/mix/01ac021b_3.1975_209o0105_-3.1975.wav
#   inflating: min/tt/mix/01aa0113_2.8184_209a010x_-2.8184.wav
#   inflating: min/tt/mix/01ao030u_2.0726_209o010l_-2.0726.wav
#   inflating: min/tt/mix/01ac020q_0.55115_209a010d_-0.55115.wav
#   inflating: min/tt/mix/01ac020d_3.2831_209a0108_-3.2831.wav
#   inflating: min/tt/mix/01ac020k_3.9671_209o010o_-3.9671.wav
#   inflating: min/tt/mix/01aa010k_2.1247_209a010a_-2.1247.wav
#   inflating: min/tt/mix/01ac020k_0.99002_209o010h_-0.99002.wav
#   inflating: min/tt/mix/01ao030u_1.7102_209a010q_-1.7102.wav
#   inflating: min/tt/mix/01ac020f_4.1179_209c0101_-4.1179.wav
#   inflating: min/tt/mix/01ao030v_0.19159_209a010k_-0.19159.wav
#   inflating: min/tt/mix/01ac0204_4.7097_209o0102_-4.7097.wav
#   inflating: min/tt/mix/01ao0305_0.10154_209c010i_-0.10154.wav
#   inflating: min/tt/mix/01aa010b_0.12432_209o010e_-0.12432.wav
#   inflating: min/tt/mix/01ao0316_1.6981_209a010n_-1.6981.wav
#   inflating: min/tt/mix/01ac020b_3.1468_209c010g_-3.1468.wav
#   inflating: min/tt/mix/01ao031b_2.1841_209a0107_-2.1841.wav
#   inflating: min/tt/mix/01aa010j_0.81737_209o010a_-0.81737.wav
#   inflating: min/tt/mix/01aa010s_4.6717_209o010n_-4.6717.wav
#   inflating: min/tt/mix/01ao030m_0.70183_209a0104_-0.70183.wav
#   inflating: min/tt/mix/01ao030c_2.3661_209a010l_-2.3661.wav
#   inflating: min/tt/mix/01ac020t_2.0334_209c010a_-2.0334.wav
#   inflating: min/tt/mix/01ac020x_3.472_209c0101_-3.472.wav
#   inflating: min/tt/mix/01ao030g_0.80276_209c0107_-0.80276.wav
#   inflating: min/tt/mix/01ac0201_4.8119_209o0103_-4.8119.wav
#   inflating: min/tt/mix/01aa0112_3.8726_209a010y_-3.8726.wav
#   inflating: min/tt/mix/01ac021b_3.3224_209o010j_-3.3224.wav
#   inflating: min/tt/mix/01ac020d_4.3932_209a010i_-4.3932.wav
#   inflating: min/tt/mix/01ac020m_2.0064_209c010p_-2.0064.wav
#   inflating: min/tt/mix/01ao031a_0.88148_209c010c_-0.88148.wav
#   inflating: min/tt/mix/01ac0213_3.3792_209o010b_-3.3792.wav
#   inflating: min/tt/mix/01aa0102_4.0757_209o0108_-4.0757.wav
#   inflating: min/tt/mix/01ac021e_1.9127_209o010p_-1.9127.wav
#   inflating: min/tt/mix/01ao030w_4.9629_209o010d_-4.9629.wav
#   inflating: min/tt/mix/01ao030a_0.51442_209o0106_-0.51442.wav
#   inflating: min/tt/mix/01ao030n_4.3726_209c0104_-4.3726.wav
#   inflating: min/tt/mix/01ao030i_3.6273_209a010g_-3.6273.wav
#   inflating: min/tt/mix/01ac0210_0.7969_209o010h_-0.7969.wav
#   inflating: min/tt/mix/01ac0217_2.6483_209o010a_-2.6483.wav
#   inflating: min/tt/mix/01aa0108_3.4995_209a010n_-3.4995.wav
#   inflating: min/tt/mix/01ac020s_1.3241_209a010o_-1.3241.wav
#   inflating: min/tt/mix/01ac020f_4.4789_209c0102_-4.4789.wav
#   inflating: min/tt/mix/01ao030e_4.5119_209a010w_-4.5119.wav
#   inflating: min/tt/mix/01ao030q_3.327_209c010g_-3.327.wav
#   inflating: min/tt/mix/01ao031d_0.32387_209c010a_-0.32387.wav
#   inflating: min/tt/mix/01aa0108_3.0868_209a0114_-3.0868.wav
#   inflating: min/tt/mix/01ao030q_2.6388_209o010n_-2.6388.wav
#   inflating: min/tt/mix/01aa0114_3.0485_209a0102_-3.0485.wav
#   inflating: min/tt/mix/01ac0215_2.4269_209o010m_-2.4269.wav
#   inflating: min/tt/mix/01ac020e_2.8781_209a010h_-2.8781.wav
#   inflating: min/tt/mix/01ac0217_0.89304_209a010y_-0.89304.wav
#   inflating: min/tt/mix/01ac0210_0.052248_209c0108_-0.052248.wav
#   inflating: min/tt/mix/01ac020r_3.2359_209c0102_-3.2359.wav
#   inflating: min/tt/mix/01aa010m_0.55609_209o010n_-0.55609.wav
#   inflating: min/tt/mix/01ao031a_2.6743_209c010q_-2.6743.wav
#   inflating: min/tt/mix/01ac021g_0.11994_209o0104_-0.11994.wav
#   inflating: min/tt/mix/01ao0315_3.8886_209o010l_-3.8886.wav
#   inflating: min/tt/mix/01ac020i_1.3021_209c010j_-1.3021.wav
#   inflating: min/tt/mix/01ao0310_2.8044_209a010q_-2.8044.wav
#   inflating: min/tt/mix/01ao030c_4.2717_209a010o_-4.2717.wav
#   inflating: min/tt/mix/01ac021b_1.1891_209c010c_-1.1891.wav
#   inflating: min/tt/mix/01aa0113_2.077_209a010h_-2.077.wav
#   inflating: min/tt/mix/01ac0207_2.8373_209o0108_-2.8373.wav
#   inflating: min/tt/mix/01ao0319_1.5938_209a010t_-1.5938.wav
#   inflating: min/tt/mix/01aa010w_2.9732_209o0105_-2.9732.wav
#   inflating: min/tt/mix/01ac0206_3.3107_209o0108_-3.3107.wav
#   inflating: min/tt/mix/01aa010a_4.6492_209c010j_-4.6492.wav
#   inflating: min/tt/mix/01ao031e_1.1699_209c010e_-1.1699.wav
#   inflating: min/tt/mix/01aa010o_3.6821_209c0108_-3.6821.wav
#   inflating: min/tt/mix/01ao030p_4.7378_209o010d_-4.7378.wav
#   inflating: min/tt/mix/01ao030t_1.3371_209a010a_-1.3371.wav
#   inflating: min/tt/mix/01aa010k_3.8019_209a010j_-3.8019.wav
#   inflating: min/tt/mix/01ac0211_1.9537_209a0104_-1.9537.wav
#   inflating: min/tt/mix/01ao030v_2.2043_209c010l_-2.2043.wav
#   inflating: min/tt/mix/01aa010c_2.1421_209a010n_-2.1421.wav
#   inflating: min/tt/mix/01ao0315_4.4713_209c010j_-4.4713.wav
#   inflating: min/tt/mix/01ao030m_0.55878_209o010o_-0.55878.wav
#   inflating: min/tt/mix/01aa010u_1.8095_209c010l_-1.8095.wav
#   inflating: min/tt/mix/01ac020s_1.1303_209a010d_-1.1303.wav
#   inflating: min/tt/mix/01ac020r_4.789_209o010b_-4.789.wav
#   inflating: min/tt/mix/01aa010t_4.862_209a010a_-4.862.wav
#   inflating: min/tt/mix/01aa010t_3.2298_209a010v_-3.2298.wav
#   inflating: min/tt/mix/01ao0308_1.9995_209o010m_-1.9995.wav

# %% [markdown]
# # Preprocessing & Dataset & DataLoader

# %% [markdown]
# ## Preprocessing directory file & reading it as json

# %%
import os
import json
import librosa
def preprocess_one_dir(in_dir, out_dir, filename,sample_rate):
    file_infos = []
    wav_list = os.listdir(in_dir)
    for wav in wav_list:
        if not wav.endswith('.wav'):
            continue
        wav_path = os.path.join(in_dir, wav)
        samples,_ = librosa.load(wav_path, sr = sample_rate)
        file_infos.append((wav_path, len(samples)))
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
    with open(os.path.join(out_dir, filename + '.json'), 'w') as f:
        json.dump(file_infos, f, indent = 4)

def preprocess():
    for data_type in ['tr', 'cv', 'tt']:
        for speaker in ['mix', 's1', 's2']:
            preprocess_one_dir(os.path.join('min',data_type, speaker),
                               os.path.join('out',data_type), speaker, sample_rate = 8000)

# %% [markdown]
# ## Some useful tools, load_wav_file to varialble (batched)

# %%
def load_mixtures_and_sources(batch):

    mixtures, sources = [], []

    mix_infos, s1_infos, s2_infos, sample_rate = batch

    for mix_info, s1_info, s2_info in zip(mix_infos, s1_infos, s2_infos):
        mix_path = mix_info[0]
        s1_path = s1_info[0]
        s2_path = s2_info[0]

        assert mix_info[1] == s1_info[1] and s1_info[1] == s2_info[1]

        # read wav file
        mix, _ = librosa.load(mix_path, sr = sample_rate)
        s1, _ = librosa.load(s1_path, sr = sample_rate)
        s2, _ = librosa.load(s2_path, sr = sample_rate)

        s = np.dstack((s1, s2))[0]

        utt_len = mix.shape[-1]

        mixtures.append(mix)
        sources.append(s)

    return mixtures, sources


def load_mixtures(batch):

    mixtures, filenames = [], []

    mix_infos, sample_rate = batch

    for mix_info in mix_infos:
        mix_path = mix_info[0]

        mix,_ = librosa.load(mix_path, sr = sample_rate)
        mixtures.append(mix)
        filenames.append(mix_path)

    return mixtures, filenames

def pad_list(xs, pad_value):
    n_batch = len(xs)
    max_len = max(x.size(0) for x in xs)
    pad = xs[0].new(n_batch, max_len, *xs[0].size()[1:]).fill_(pad_value)
    for i in range(n_batch):
        pad[i, :xs[i].size(0)] = xs[i]
    return pad

# %% [markdown]
# ## Dataset & DataLoader

# %%
import torch.utils.data as data
def sort(infos): 
    return sorted(infos, key=lambda info: int(info[1]), reverse=True)
# Reading Data to Dataset, adding batch_size
# output a object (list), 
class AudioDataset(data.Dataset):

    def __init__(self, json_dir, batch_size, sample_rate = 8000):

        super(AudioDataset, self).__init__()
        mix_json = os.path.join(json_dir, 'mix.json')
        s1_json = os.path.join(json_dir, 's1.json')
        s2_json = os.path.join(json_dir, 's2.json')

        with open(mix_json, 'r') as f:
            mix_infos = json.load(f)
        with open(s1_json, 'r') as f:
            s1_infos = json.load(f)
        with open(s2_json, 'r') as f:
            s2_infos = json.load(f)
        
        sorted_mix_infos = sort(mix_infos)
        sorted_s1_infos = sort(s1_infos)
        sorted_s2_infos = sort(s2_infos)

        
        minibatch = []
        start = 0
        while True:
            end = min(len(mix_infos), start + batch_size)

            minibatch.append([sorted_mix_infos[start:end],
                              sorted_s1_infos[start:end],
                              sorted_s2_infos[start:end],
                              sample_rate])
            if end == len(mix_infos):
                break
            start = end

        self.minibatch = minibatch

    def __getitem__(self, index):
        return self.minibatch[index]

    def __len__(self):
        return len(self.minibatch)


class AudioDataLoader(data.DataLoader):

    def __init__(self, *args, **kwargs):
        super(AudioDataLoader, self).__init__(*args, **kwargs)
        self.collate_fn = _collate_fn


def _collate_fn(batch):


    assert len(batch) == 1
    mixtures, sources = load_mixtures_and_sources(batch[0])

    ilens = np.array([mix.shape[0] for mix in mixtures])

    pad_value = 0
    mixtures_pad = pad_list([torch.from_numpy(mix).float() for mix in mixtures], pad_value)
    ilens  = torch.from_numpy(ilens)
    sources_pad = pad_list([torch.from_numpy(s).float() for s in sources], pad_value)

    sources_pad = sources_pad.permute((0, 2, 1)).contiguous()

    return mixtures_pad, ilens, sources_pad

# %%
class EvalDataset(data.Dataset):

    def __init__(self, mix_dir, mix_json, batch_size, sample_rate = 8000):

        super(EvalDataset, self).__init__()

        assert mix_dir != None or mix_json != None
        if mix_dir is not None:
            preprocess_one_dir(mix_dir, mix_dir, 'mix', sample_rate = sample_rate)
            mix_json = os.path.join(mix_dir, 'mix.json')
        
        with open(mix_json, 'r') as f:
            mix_infos = json.load(f)

        sorted_mix_infos = sort(mix_infos)
        mini_batch = []
        start = 0
        while True:
            end = min(len(sorted_mix_infos), start + batch_size)
            mini_batch.append([sorted_mix_infos[start:end], sample_rate])
            if end == len(sorted_mix_infos):
                break
            start = end
        self.mini_batch = mini_batch

    def __getitem__(self, index):
        return self.mini_batch[index]

    def __len__(self):
        return len(self.mini_batch)


class EvalDataLoader(data.DataLoader):

    def __init__(self, *args, **kwargs):
        super(EvalDataLoader, self).__init__(*args, **kwargs)
        self.collate_fn = __collate_fn_eval

    
def __collate_fn_eval(batch):
    assert len(batch) == 1
    mixtures, filenames = load_mixtures(batch[0])

    ilens = np.array([mix.shape[0] for mix in mixtures])

    pad_value = 0
    mixtures_pad = padlist([torch.from_numpy(mix).float() for mix in mixtures], pad_value)

    ilens = torch.from_numpy(ilens)

    return mixtures_pad, ilens, filenames

# %% [markdown]
# # GRU

# %%
class GRUModel(nn.Module):
    def __init__(self, original_shape = 0):
        super(GRUModel, self).__init__()
        self.shape = original_shape
        self.gru = torch.nn.GRU(128, 128, 4, dropout=0.2, batch_first=True)
        self.fc_input = nn.Sequential(*[
                nn.Linear(self.shape, 256),
                nn.ReLU(),
                nn.Dropout(0.4),
                nn.Linear(256, 128)
            ])
        
        
        self.gru = nn.ModuleList([torch.nn.GRU(128, 128, 1, batch_first=True) for _ in range(4)])
        self.ln = nn.ModuleList([torch.nn.LayerNorm(128) for _ in range(4)])
        # self.bn = nn.ModuleList([torch.nn.BNorm(128) for _ in range(4)])

        self.fc_output = nn.Sequential(*[
                nn.Linear(128, 256),
                nn.ReLU(),
                nn.Dropout(0.2),
                nn.Linear(256, self.shape),
                nn.ReLU()
            ])

    def total_param(self):
        return sum([p.numel() for p in self.parameters()]) / 1000.0 / 1000.0

    def forward(self, x):
        mix = x
        out = self.fc_input(x).cuda()
        out = out.view(out.size(0),1, out.size(1))

        for i in range(4):
            out, _ = self.gru[i](out)
            out = self.ln[i](out)

        mask = self.fc_output(out)
        estimated_s1 = mix.view(10,1,self.shape) * mask
        estimated_s2 = mix.view(10,1,self.shape) - estimated_s1
        final = torch.stack([estimated_s1, estimated_s2], 1)
 
        return final.view(10,2,self.shape)

# %%
import time
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01)

print('Training...')
start = time.time()
total_loss = 0

for epoch in range(0, 10):
    for i, (dataset) in enumerate(tr_dataloader):
        padded_mixture, mixture_lengths, padded_source = dataset

        padded_mixture = padded_mixture.cuda()
        mixture_lengths = mixture_lengths.cuda()
        padded_source = padded_source.cuda()
        model = GRUModel(padded_source.size(-1))
        model.cuda()
        model.train()
        estimate_source = model(padded_mixture)

        loss, max_snr, estimate_source, reorder_estimate_source = \
        cal_loss(padded_source, estimate_source, mixture_lengths)
        
        optimizer.zero_grad()

        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        tr_avg_loss = total_loss / (i + 1)
        print('-' * 100)
        print('Train Summary | End of Epoch {0} | Time {1: .2f}s | Train Loss {2: .3f}'.format(epoch + 1, time.time() - start, tr_avg_loss))
        print('-' * 100)
# Out:
# Training...
# ----------------------------------------------------------------------------------------------------
# Train Summary | End of Epoch 1 | Time  29.74s | Train Loss  5.425
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Train Summary | End of Epoch 1 | Time  31.23s | Train Loss  5.336
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Train Summary | End of Epoch 1 | Time  32.93s | Train Loss  5.193
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Train Summary | End of Epoch 1 | Time  34.06s | Train Loss  5.068
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Train Summary | End of Epoch 1 | Time  57.44s | Train Loss  5.073
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Train Summary | End of Epoch 1 | Time  60.11s | Train Loss  4.994
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Train Summary | End of Epoch 1 | Time  61.38s | Train Loss  5.015
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-214-cab88baaa834> in <module>()
#      13         mixture_lengths = mixture_lengths.cuda()
#      14         padded_source = padded_source.cuda()
# ---> 15         model = GRUModel(padded_source.size(-1))
#      16         model.cuda()
#      17         model.train()
#
# <ipython-input-210-a0fa54950a23> in __init__(self, original_shape)
#       5         self.gru = torch.nn.GRU(128, 128, 4, dropout=0.2, batch_first=True)
#       6         self.fc_input = nn.Sequential(*[
# ----> 7                 nn.Linear(self.shape, 256),
#       8                 nn.ReLU(),
#       9                 nn.Dropout(0.4),
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/linear.py in __init__(self, in_features, out_features, bias)
#      81         else:
#      82             self.register_parameter('bias', None)
# ---> 83         self.reset_parameters()
#      84
#      85     def reset_parameters(self) -> None:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/linear.py in reset_parameters(self)
#      84
#      85     def reset_parameters(self) -> None:
# ---> 86         init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#      87         if self.bias is not None:
#      88             fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/init.py in kaiming_uniform_(tensor, a, mode, nonlinearity)
#     382     bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
#     383     with torch.no_grad():
# --> 384         return tensor.uniform_(-bound, bound)
#     385
#     386
#
# KeyboardInterrupt:

# %% [markdown]
# --------------------------**Tasnet**----------------------------------

# %% [markdown]
# # Conv - TasNet

# %%
class ConvTasNet(nn.Module):

    '''
    N : number of filters in autoencoder
    L : Length of the filters (in samples)
    B : number of channels in bottleneck 1 x 1-conv block
    H : number of channels in convolutional blocks
    P : kernel size in convolutional blocks
    X : number of convolutional blocks in each repeat
    R : number of repeats
    C : number of speakers

    Encoder 
    -> 1-D Conv 
    -> Layer Norm 
    -> 1*1 Conv 
    -> 1-D Conv -> SUM UP -> PReLU -> 1*1 Conv -> Sigmoid -> 1-D Conv -> Seperated sources
    Encoder : para  (L, N) number of filter & length of filter 



    '''

    def __init__(self, N, L, B, H, P, x, R, C, norm_type = 'gLN', causal = False, mask_nonlinear = 'relu'):
        super(ConvTasNet,self).__init__()
        # Hypyer-parameters
        self.N, self.L, self.B, self.H, self.P, self.X, self.R, self.C = N, L, B, H, P, X, R, C
        self.norm_type = norm_type
        self.causal = causal
        self.mask_nonlinear = mask_nonlinear
        self.encoder = Encoder(L, N)
        self.seperator = TemporalConvNet(N, B, H, P, X, R, C, norm_type, causal, mask_nonlinear)
        self.decoder = Decoder(N, L)

        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_normal_(p)


    def forward(self, mixture):

        mixutre_w = self.encoder(mixture)
        est_mask = self.separator(mixture_w)
        est_source = self.decoder(mixture_w, est_mask)

        T_origin = mixture.size(-1)
        T_conv = est_source.size(-1)
        est_source = F.pad(est_source, (0, T_origin - T_conv))
        return est_source

# %% [markdown]
# #AutoEncoder

# %%
# AutoEncoder

class Encoder(nn.Module):
    """
    N: number of filters in autoencoder
    L: Length of the filters (in samples)

nn.Conv1d:
input size = (Batch_size, Number of channels, length of signal sequence)
output size = (Batch_size, number of output channels, length of )

mixture shape =  [batch_size, sample]
    """ 
    def __init__(self, L, N):
        super(Encoder, self).__init__()

        self.L = L
        self.N = N

        self.conv1d_U = nn.Conv1d(1, N, kernel_size = L, stride = L//2, bias = False)

    def forward(self, mixture):
        mixture = torch.unsqueeze(mixture, 1)   # shape [batch_size, sample] -> [batch_size, 1, sample]
        mixture_encoded = F.relu(self.conv1d_U(mixture))  
        return mixture_encoded                  # shape [batch_size, N, K]              K = (T-L)/(L/2) + 1


class Decoder(nn.Module):
    def __init__(self, N, L):
        super(Decoder, self).__init__()

        self.N, self.L = N, L

        self.basis_signals = nn.Linear(N, L, bias = False)

    def forward(self, mixture_encoded, est_mask):

        '''
        mixture_encoded shape   [M, N, K]
        est_mask shape  [M, C, N, K]
        '''

        

        source_w = torch.unsqueeze(mixture_encoded, 1) * est_mask  #[M, C, N, K]
        source_w = torch.transpose(source_w, 2, 3)                 #[M, C, K, N]

        est_source = self.basis_signals(source_w)
        est_source = overlap_and_add(est_source, self.L//2)
        return est_source


def overlap_and_add(signal, frame_step):
    outer_dimensions = signal.size()[:-2]
    frames, frame_length = signal.size()[-2:]

    subframe_length = math.gcd(frame_length, frame_step)
    subframe_step = frame_step // subframe_length
    subframes_per_frame = frame_length //subframe_length
    output_size = frame_step * (frames - 1) + frame_length
    output_subframes = output_size // subframe_length

    subframe_signal = signal.view(*outer_dimensions, -1, subframe_length)

    frame = torch.arange(0, output_subframes).unfold(0, subframes_per_frame, subframe_step)
    frame = signal.new_tensor(frame).long()
    frame = frame.contiguous().view(-1)

    result = signal.new_zeros(*outer_dimensions, output_subframes, subframe_length)
    result.index_add_(-2, frame, subframe_signal)
    result = result.view(*outer_dimensions, -1)

    return result

# %% [markdown]
# # Block

# %%
class TemporalConvNet(nn.Module):

    '''
    N : number of filters in autoencoder
    B : number of channels in bottleneck 1 x 1-conv block
    H : number of channels in convolutional blocks
    P : kernel size in convolutional blocks
    X : number of convolutional blocks in each repeat
    R : number of repeats
    C : number of speakers


    class : TemporalBlock
    class : ChannelwiselayerNorm
    
    '''


    def __init__(self, N, B, H, P, X, R, C, norm_type = 'gLN', causal = False, mask_nonlinear = 'relu'):
        super(TemporalConvNet, self).__init__()
        self.C = C
        self.mask_nonlinear = mask_nonlinear
        
        layer_norm = ChannelwiseLayerNorm(N)

        bottleneck_conv1x1 = nn.Conv1d(N, B, 1, bias = False)

        repeats = []

        for r in range(R):
            blocks = []
            for x in range(X):
                dilation = 2**x
                padding = (P - 1) * dilation if causal else (P - 1) * dilation//2

                blocks += [TemporalBlock(B, H, P, stride = 1,
                                         padding = padding,
                                         dilation = dilation,
                                         norm_type = norm_type,
                                         causal = causal)]
            repeats += [nn.Sequential(*blocks)]
        
        temporal_con_net = nn.Sequential(*repeats)

        mask_conv1x1 = nn.Conv1d(B, C*N, 1, bias = False)

        self.network = nn.Sequential(layer_norm,
                                     bottleneck_conv1x1,
                                     temporal_con_net,
                                     mask_conv1x1)
        
    def forward(self, mixture_w):

        M, N, K = mixture_w.size()
        score = self.network(mixture_W)
        score = score.view(M, self.C, N, K)

        if self.mask_nonlinear == 'softmax':
            est_mask = F.softmax(score, dim = 1)
        elif self.mask_nonlinear == 'relu':
            est_mask = F.relu(score)
        return est_mask



class TemporalBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, norm_type = 'gLN', causal = False):

        super(TemporalBlock, self).__init__()
        
        conv1x1 = nn.Conv1d(in_channels, out_channels, 1, bias = False)
        prelu = nn.PReLU()
        norm = chose_norm(norm_type, out_channels)
        dsconv = DepthwiseSeparableConv(out_channels, in_channels, kernel_size, stride, padding, dilation, norm_type, causal)

        self.net = nn.Sequential(conv1x1, prelu, norm, dsconv)


    def forward(self, x):

        residual = x
        out = self.net(x)
        return out + residual


def chose_norm(norm_type, channel_size):

    if norm_type == "glN":
        return GlobalLayerNorm(channel_size)
    elif norm_type == "cLN":
        return ChannelwiselayerNorm（channel_size)
    else:
        return nn.BatchNorm1(channel_size)

# %% [markdown]
# # Depthwise Conv + Pointwise Conv

# %%
class DepthwiseSeparableConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, norm_type = "gLN", causal = False):

        super(DepthwiseSeparableConv, self).__init__()

        depthwise_conv = nn.Conv1d(in_channels, in_channels, kernel_size, 
                                   stride = stride, padding = padding,
                                   dilation = dilation, groups = in_channels, bias = False)
        
        if causal:
            chomp = Chomp1d(padding)
        
        prelu = nn.PReLU()
        norm = chose_norm(norm_type, in_channels)

        pointwise_conv = nn.Conv1d(in_channels, out_channels, 1, bias = False)

        if causal:
            self.net = nn.Sequential(depthwise_conv, chomp, prelu, norm, pointwise_conv)
        else:
            self.net = nn.Sequential(depthwise_conv, prelu, norm, pointwise_conv)

    def forward(self, x):
        return self.net(x)

class Chomp1d(nn.Module):

    def __init__(self, chomp_size):
        super(Chomp1d, self).__init__()
        self.chomp_size = chomp_size

    def forward(self, x):
        return x[:, :, :-self.chomp_size].contiguous()

# %% [markdown]
# # Norm Layer

# %%
class ChannelwiselayerNorm(nn.Module):

    ''' channel wise layer normalization (cLN)'''

    def __init__(self, channel_size):
        super(ChannelwiselayerNorm, self).__init__
        self.gamma = nn.Parameter(torch.Tensor(1, channel_size, 1))  # [1, N, 1]
        self.beta = nn.Parameter(torch.Tensor(1, channel_size, 1)) # [1, N, 1]
        self.reset_parameters()

    def reset_parameters():
        self.gamma.data.fill_(1)
        self.beta.data.zero_()

    def forward(self, y):
        '''
        Args: y: [batch size, channel size, length] 

        gLN_y: [M, N, K]
        '''

        var = torch.pow(y, dim = 1, keepdim = True, unbiased = False)  #[M, 1, K]
        cLN_y = self.gamma * (y - mean)/ torch.pow(var + EPS, 0.5) + self.beta

        return cLN_y


class GlobalLayerNorm(nn.Module):
    
    def __ini__(self, channel_size):
        
        super(GlobalLayerNorm, self).__init__()
        self.gamma = nn.Parameter(torch.Tensor(1, channel_size, 1))  #[1, N, 1]
        self.beta = nn.Parameter(torch.Tensor(1, channel_size, 1))   #[1, N, 1]

    def reset_parameters():
        self.gamma.data.fill_(1)
        self.beta.data.zero_()

    def forward(self, y):

        mean = y.mean(dim = 1, keepdim = True).mean(dim = 2,keepdim = True)   #[M, mean, mean]
        var = (torch.pow(y - mean)).mean(dim = 1, keepdim = True).mean(dim = 2, keepdim = True)
        gLN_y = self.gamma * (y - mean) / torch.pow(var + EPS, 0.5) + self.beta

        return gLN_y

# %% [markdown]
# # PIT Loss function

# %%
EPS = 1e-8
def get_mask(source, source_lengths):
    B, _, T = source.size()
    mask = source.new_ones((B, 1, T))
    
    for i in range(B):
        mask[i, :, source_lengths[i]:] = 0

    return mask

def cal_loss(source, estimate_source, source_lengths, PIT = True):


    if PIT:
        max_snr, perms, max_snr_idx = cal_si_snr_with_pit(source, estimate_source, source_lengths)
        loss = 0 - torch.mean(max_snr)
        reorder_estimate_source = reorder_source(estimate_source, perms, max_snr_idx)
        return loss, max_snr, estimate_source, reorder_estimate_source
    else:
        si_snr = cal_si_snr(source,estimate_source, source_lengths)
        loss = 0 - torch.mean(si_snr)
        return loss, si_snr, estimate_source, estimate_source


def cal_si_snr(source, estimate_source, source_lengths):

    assert source.size() == estimate_source.size()

    B, C, T = source.size()

    mask = get_mask(source, source_lengths)
    estimate_source *= mask

    num_samples = source_lengths.view(-1, 1, 1).float()
    mean_target = torch.sum(source, dim = 2, keepdim = True)/num_samples
    mean_estimate = torch.sum(estimate_source, dim =2, keepdim = True)/num_samples

    zero_mean_target = source - mean_target
    zero_mean_estimate = estimate_source - mean_estimate

    zero_mean_target *= mask
    zero_mean_estimate *= mask

    s_target = zero_mean_target
    s_estimate = zero_mean_estimate

    pair_wise_dot = torch.sum(s_estimate * s_target, dim = 2, keepdim = True)
    s_target_energy = torch.sum(s_target ** 2, dim = 2, keepdim = True) + EPS
    pair_wise_proj = pair_wise_dot * s_target / s_target_energy

    e_noise = s_estimate - pair_wise_proj

    pair_wise_si_snr = torch.sum(pair_wise_proj ** 2, dim = 2, keepdim = True) / (torch.sum(e_noise ** 2, dim =2, keepdim = True) + EPS)
    pair_wise_si_snr = 10 * torch.log10(pair_wise_si_snr + EPS)
    si_snr = torch.mean(pair_wise_si_snr, dim = -1, keepdim = True)


    return si_snr

def cal_si_snr_with_pit(source, estimate_source, source_lengths):

    '''
    source  [B, C, T]
    estimate_source [B, C, T]
    source_lengths [B]
    '''

    assert source.size() == estimate_source.size()
    B, C, T = source.size()
    mask = get_mask(source, source_lengths)                                       # [B, 1, T]  original = 1, padded = 0
    estimate_source *= mask                                                       # [B, 1, T]  

    num_samples = source_lengths.view(-1, 1, 1).float()                           # [B, 1, 1]
    mean_target = torch.sum(source, dim = 2, keepdim = True) / num_samples        # [B, C, 1 (sum)] / [B, 1, 1]  = [B, C, mean]
    mean_estimate = torch.sum(estimate_source, dim = 2, keepdim = True) / num_samples  # [B, C, 1]
    zero_mean_target = source - mean_target                                       # [B, C, T] - [B, C, T]
    zero_mean_estimate = estimate_source - mean_estimate

    zero_mean_target *= mask
    zero_mean_estimate *= mask

    s_target = torch.unsqueeze(zero_mean_target, dim = 1)                         # [B, 1, C, T]
    s_estimate = torch.unsqueeze(zero_mean_estimate, dim = 2)                     # [B, C, 1, T]

    pair_wise_dot = torch.sum(e_stimate * s_target, dim = 3, keepdim = True)      # [B, C, C, 1]
    s_target_energy = torch.sum(s_target ** 2, dim = 3, keepdim = True)           # [B, 1, C, 1]
    pair_wise_proj = pair_wise_dot * s_target / s_target_energy                   # [B, C, C, T、
    

    e_noise = s_estimate - pair_wise_proj                                         # [B, C, C, T]

    pair_wise_si_snr = torch.sum(pair_wise_proj ** 2, dim = 3)/(torch.sum(e_noise **2, dim = 3) + EPS)  # [B, C, C] / [B, C, C]  
    pair_wise_si_snr = 10 * torch.log10(pair_wise_si_snr + EPS)                   # [B, C, C]

    perms = source.new_tensor(list(permutation(range(C))), dtype = torch.long)    # [C!, C]

    index = torch.unsqueeze(perms, 2)                                             # [C!, C, 1]
    perms_one_hot = source.new_zeros((*perms.size(), C)).scatter_(2, index, 1)    # [C!, C, C]

    snr_set = torch.einsum("bij,pij -> bp", [pair_wise_si_snr, perms_one_hot])    # []
    max_snr_idx = torch.argmax(snr_set, dim = 1)                                  # [B]
    max_snr, _ = torch.max(snr_set, dim = 1, keepdim = True)                      
    max_snr /= c
    return max_snr, perms, max_snr_idx
    




def reorder_source(source, perms, max_snr_idx):
    '''
    source:  [B, C, T]
    perms: [C!, C]
    max_snr_idx [B]


    '''
    B, C, *_ = source.size()
    max_snr_perm = torch.index_select(perms, dim = 0, index = max_snr_idx)

    reorder_source = torch.zeros_like(source)

    for b in range(B):
        for c in range(C):
            reorder_source[b, c] = source[b, max_snr_perm[b][c]]
    return reorder_source

# %% [markdown]
# # Training

# %%
def run_one_epoch(epoch, cross_valid = False):
    start = time.time()
    total_loss = 0

    data_loader = tr_loader if not cross_valid else cv_loader


    if visdom_epoch and not cross_valid:
        vis_opts_epoch = dict(title = visdom_id + 'epoch' + str(epoch), ylabel = 'Loss', xlabel = 'Epoch')
        vis_window_epoch = None
        vis_iters = torch.arange(1, len(data_loader) + 1)
        vis_iters_loss = torch.Tensor(len(data_loader))

    for i, data in enumerate(data_loader):
        padded_mixture, mixture_lengths, padded_source = data
        if use_cuda:
            padded_mixture = padded_mixture.cuda()
            mixture_lengths = mixture_lengths.cuda()
            padded_source = padded_source.cuda()
        estimate_source = model(padded_mixture)
        loss, max_snr, estimate_source, reorder_estimate_source =\
        cal_los(padded_source, estimate_source, mixture_lengths, pit)
        if not cross_valid:
            optimizer.zero_grad()
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm)

            optimizer.step()
        total_loss += loss.item()

        if i % print_freq == 0:
            print('Epoch {0} | Iter {1} | Average Loss {2:.3f} | '
                      'Current Loss {3:.6f} | {4:.1f} ms/batch'.format(
                          epoch + 1, i + 1, total_loss / (i + 1),
                          loss.item(), 1000 * (time.time() - start) / (i + 1)),
                      flush=True)
        
        if visdom_epoch and not cross_valid:
            vis_iters_loss[i] = loss.item()
            if i % print_freq == 0:
                x_axis = vis_iters[:i+1]
                y_axis = vis_iters_loss[:i+1]
                if vis_window_epoch is None:
                    vis_window_epoch = vis.line(X = x_axis, Y = y_axis, opts = vis_opts_epoch)
                else:
                    vis.line(X = x_axis, Y = y_axis, win = vis_window_epoch, update = 'replace')
    return total_loss / (i + 1)



def train():

    for epoch in range(start_epoch, epochs):
        print('Traning...')
        model.train()
        start = time.time()
        tr_avg_loss = run_one_epoch(epoch)
        print('*' * 100)
        print('Train Summary | End of Epoch {0} | Time {1:.2f}s | '
                  'Train Loss {2:.3f}'.format(
                      epoch + 1, time.time() - start, tr_avg_loss))
        print('*' * 100)

        if checkpoint:
            file_path = os.path.join(
                self.save_folder,  'epoch%d.pth.tar' % (epoch + 1)
            )
            torch.save(model.module.serialize(model.module, optimizer, epoch + 1, tr_loss = tr_loss, cv_loss = cv_loss)
            print('Saving checkpoint model to %s' % file_path)

        print('Cross Validation')
        model.eval()
        val_loss = run_one_epoch(epoch, cross_valid = True)
        print('*' * 100)
        print('Valid Summary | End of Epoch {0} | Time {1:.2f}s | '
                  'Valid Loss {2:.3f}'.format(
                      epoch + 1, time.time() - start, val_loss))
        print('*' * 100)

        if half_lr:
            if val_loss >= pre_val_loss:
                val_no_impv += 1
                if val_no_impv >= 3:
                    halving = True
                if val_no_impv >= 10 and early_stop:
                    print('No improvement, early stopping')
                    break
            else:
                val_no_impv = 0

        if halving:
            optim_state = optimizer.state_dict()
            optim_state['param_groups'][0]['lr'] = \
                optim_state['param_grous'][0]['lr'] / 2.0
            optimizer.load_state_dict(optim_state)
            print('Learning rate adjusted to: {lr:.6f}'.format(
                    lr=optim_state['param_groups'][0]['lr']))
            halving = False
        prev_val_loss = val_loss


        tr_loss[epoch] = tr_avg_loss
        cv_loss[epoch] = val_loss

        if val_loss < best_val_loss:
            best_val_loss = val_loss
                file_path = os.path.join(save_folder, model_path)
                torch.save(model.module.serialize(model.module,
                                    optimizer, epoch + 1,
                                    tr_loss= tr_loss,
                                    cv_loss= cv_loss),file_path)
                print("Find better validated model, saving to %s" % file_path)
        if visdom:
            x_axis = vis_epochs[0:epoch + 1]
            y_axis = torch.stack(
                (tr_loss[0:epoch + 1], cv_loss[0:epoch + 1]), dim = 1
            )

            if vis_window is None:
                vis_window = vis.line(
                    X = x_axis,
                    Y = y_axis,
                    opts = vis_opts
                )
            else:
                vis.line(
                    X = x_axis.unsqueeze(0).expand(y_axis.size(1),
                        x_axis.size(0)).transpose,
                    Y = y_axis,
                    win = vis_window,
                    update = 'replace'
                )

# %% [markdown]
# # Main

# %%
tr_dataset =
cv_dataset =
tr_dataloader =
cv_dataloader =

data = {}

model = ConvTasNet()

model = torch.nn.DataParallel()
model.cuda()

if optimizer == 'sgd':
    optimizer = torch.optim.SGD(model.parameters(),
                                lr = lr,
                                momentum = momentum,
                                weight_decay = l2)
elif optimizer == 'adam':
    optimizer = torch.optim.Adam(model.parameters(),
                                 lr = lr,
                                 weight_decay = l2)
else:
    print('No optimizer provided')

run = train()
